# %%
def merge_and_sort_lists(a, b):
    # Merge the two lists and remove duplicates by converting to a set
    merged_set = set(a + b)
    
    # Convert the set back to a list and sort it
    sorted_list = sorted(list(merged_set))
    
    return sorted_list

a = [1, 2, 3, 3, 4, 5, 6]
b = [4, 4, 5, 6, 7, 8, 9]

result = merge_and_sort_lists(a, b)
print(result)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
import torch

def main():
    # Create a complex random tensor of size 4x4x4
    tensor_complex = torch.rand((4, 4, 4)) * torch.randn((4, 4, 4))

    # Manipulation: Normalize the tensor
    tensor_norm = torch.linalg.norm(tensor_complex, dim=0)
    tensor_normalized = tensor_complex / tensor_norm

    # Print the original and normalized tensors
    print("Original Complex Random Tensor:\n", tensor_complex, "\n🐺")
    print("Normalized Tensor:\n", tensor_normalized, "\n🌌")

if __name__ == "__main__":
    main()
# Out:
# Original Complex Random Tensor:
#  tensor([[[ 2.4195e-01,  1.1419e+00, -5.1360e-01,  7.8560e-02],
#          [-1.3890e+00, -5.5041e-02,  2.6267e-01, -6.7718e-02],
#          [ 1.0859e+00, -1.4606e+00,  1.1066e+00, -9.8757e-01],
#          [ 3.0283e-01, -4.4651e-01,  1.8790e-01, -2.5444e-01]],
#
#         [[ 1.0510e-01,  1.1198e+00,  1.4387e-01, -2.0473e-02],
#          [-1.9545e-02,  3.2563e-01, -4.7881e-01,  2.2485e-01],
#          [ 1.3632e-01,  4.0391e-01, -2.4819e-02, -5.2286e-01],
#          [-9.9573e-01,  2.1381e-01, -6.8939e-04, -7.9382e-01]],
#
#         [[-1.0468e-01, -3.4417e-01, -7.2647e-02, -8.9738e-01],
#          [-9.8363e-02, -5.6705e-02, -1.8017e+00, -3.8876e-01],
#          [ 4.6773e-01,  1.1016e-01,  5.6482e-02, -2.1956e-01],
#          [ 6.8318e-01, -6.0849e-01, -2.2799e-01, -1.1557e-01]],
#
#         [[ 3.0225e-01,  7.3848e-02,  8.8095e-02, -1.0003e+00],
#          [-1.7204e-01, -4.1744e-01, -3.6753e-02, -5.7324e-01],
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-2, 2, 400)

# Define the hyperbola
y = np.sqrt(1 + x**2)

# Plot the hyperbola
plt.figure(figsize=(6, 6))
plt.plot(x, y, label='y = sqrt(1 + x^2)')
plt.plot(x, -y, label='y = -sqrt(1 + x^2)')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Hyperbola')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact, FloatSlider

# Define the function to plot the hyperboloid
def plot_hyperboloid(a=1, b=1, c=1, u_range=2, v_range=2*np.pi, azim=0, elev=0):
    # Define the range of u and v values
    u = np.linspace(-u_range, u_range, 100)
    v = np.linspace(0, v_range, 100)

    # Create a meshgrid
    U, V = np.meshgrid(u, v)

    # Define the hyperboloid
    X = a * np.cosh(U) * np.cos(V)
    Y = b * np.cosh(U) * np.sin(V)
    Z = c * np.sinh(U)

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, color='b')

    # Set the viewing angle
    ax.view_init(elev=elev, azim=azim)

    # Add labels and title
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('Hyperboloid')

    # Show the plot
    plt.show()

# Create sliders for the parameters a, b, c, u_range, v_range, azim, and elev
a_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='a:')
b_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='b:')
c_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='c:')
u_range_slider = FloatSlider(min=0.1, max=5, step=0.1, value=2, description='u range:')
v_range_slider = FloatSlider(min=np.pi, max=4*np.pi, step=np.pi/4, value=2*np.pi, description='v range:')
azim_slider = FloatSlider(min=-180, max=180, step=10, value=0, description='azimuth:')
elev_slider = FloatSlider(min=-90, max=90, step=10, value=0, description='elevation:')

# Use the interact function to create the interactive plot
interact(plot_hyperboloid, a=a_slider, b=b_slider, c=c_slider, u_range=u_range_slider, v_range=v_range_slider, azim=azim_slider, elev=elev_slider)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a:', max=2.0, min=0.1), FloatSlider(value=1.0, descr…
# <function __main__.plot_hyperboloid(a=1, b=1, c=1, u_range=2, v_range=6.283185307179586, azim=0, elev=0)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact, FloatSlider

# Define the function to plot the hyperboloid
def plot_hyperboloid(a=1, b=1, c=1, u_range=2, v_range=2*np.pi):
    # Define the range of u and v values
    u = np.linspace(-u_range, u_range, 100)
    v = np.linspace(0, v_range, 100)

    # Create a meshgrid
    U, V = np.meshgrid(u, v)

    # Define the hyperboloid
    X = a * np.cosh(U) * np.cos(V)
    Y = b * np.cosh(U) * np.sin(V)
    Z = c * np.sinh(U)

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, color='b')

    # Add labels and title
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('Hyperboloid')

    # Show the plot
    plt.show()

# Create sliders for the parameters a, b, c, u_range, and v_range
a_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='a:')
b_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='b:')
c_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='c:')
u_range_slider = FloatSlider(min=0.1, max=5, step=0.1, value=2, description='u range:')
v_range_slider = FloatSlider(min=np.pi, max=4*np.pi, step=np.pi/4, value=2*np.pi, description='v range:')

# Use the interact function to create the interactive plot
interact(plot_hyperboloid, a=a_slider, b=b_slider, c=c_slider, u_range=u_range_slider, v_range=v_range_slider)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a:', max=2.0, min=0.1), FloatSlider(value=1.0, descr…
# <function __main__.plot_hyperboloid(a=1, b=1, c=1, u_range=2, v_range=6.283185307179586)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from ipywidgets import interact, FloatSlider

# Define the function to plot the hyperboloid
def plot_hyperboloid(a=1, b=1, c=1):
    # Define the range of u and v values
    u = np.linspace(-2, 2, 100)
    v = np.linspace(0, 2*np.pi, 100)

    # Create a meshgrid
    U, V = np.meshgrid(u, v)

    # Define the hyperboloid
    X = a * np.cosh(U) * np.cos(V)
    Y = b * np.cosh(U) * np.sin(V)
    Z = c * np.sinh(U)

    # Create a 3D plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.plot_surface(X, Y, Z, color='b')

    # Add labels and title
    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('Hyperboloid')

    # Show the plot
    plt.show()

# Create sliders for the parameters a, b, and c
a_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='a:')
b_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='b:')
c_slider = FloatSlider(min=0.1, max=2, step=0.1, value=1, description='c:')

# Use the interact function to create the interactive plot
interact(plot_hyperboloid, a=a_slider, b=b_slider, c=c_slider)
# Out:
# interactive(children=(FloatSlider(value=1.0, description='a:', max=2.0, min=0.1), FloatSlider(value=1.0, descr…
# <function __main__.plot_hyperboloid(a=1, b=1, c=1)>

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define the range of u and v values
u = np.linspace(-2, 2, 100)
v = np.linspace(0, 2*np.pi, 100)

# Create a meshgrid
U, V = np.meshgrid(u, v)

# Define the hyperboloid
X = np.cosh(U)*np.cos(V)
Y = np.cosh(U)*np.sin(V)
Z = np.sinh(U)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, color='b')

# Add labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('Hyperboloid')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the range of x values
x = np.linspace(-2, 2, 400)

# Define the hyperbola
y = np.sqrt(1 + x**2)

# Plot the hyperbola
plt.figure(figsize=(6, 6))
plt.plot(x, y, label='y = sqrt(1 + x^2)')
plt.plot(x, -y, label='y = -sqrt(1 + x^2)')

# Add labels and title
plt.xlabel('x')
plt.ylabel('y')
plt.title('Hyperbola')

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# ### Icosahedron
# ----

# %%
from icosphere import icosphere
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create an icosphere with a specified radius and number of subdivisions
radius = 1.0
subdivisions = 3
vertices, triangles = icosphere(radius, subdivisions)

# Plot the icosphere using matplotlib
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Extract x, y, z coordinates from vertices
x, y, z = zip(*vertices)

# Plot the icosphere's triangles
ax.plot_trisurf(x, y, triangles, z, color='cyan', edgecolor='white', linewidth=0.5, alpha=0.7)

# Set labels and display the plot
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
from mpl_toolkits.mplot3d.art3d import Poly3DCollection, Line3DCollection

# Function to generate icosahedron vertices and faces
def icosahedron():
    phi = (1 + np.sqrt(5)) / 2

    vertices = np.array([
        [-1, phi, 0], [1, phi, 0], [-1, -phi, 0], [1, -phi, 0],
        [0, -1, phi], [0, 1, phi], [0, -1, -phi], [0, 1, -phi],
        [phi, 0, -1], [phi, 0, 1], [-phi, 0, -1], [-phi, 0, 1]
    ])

    faces = np.array([
        [0, 11, 5], [0, 5, 1], [0, 1, 7], [0, 7, 10], [0, 10, 11],
        [1, 5, 9], [5, 11, 4], [11, 10, 2], [10, 7, 6], [7, 1, 8],
        [3, 9, 4], [3, 4, 2], [3, 2, 6], [3, 6, 8], [3, 8, 9],
        [4, 9, 5], [2, 4, 11], [6, 2, 10], [8, 6, 7], [9, 8, 1]
    ])

    return vertices, faces

# Function to plot icosahedron
def plot_icosahedron(ax, scale_factor):
    vertices, faces = icosahedron()
    scaled_vertices = vertices * scale_factor

    collection = Poly3DCollection([scaled_vertices[face] for face in faces], color='b', alpha=0.3, linewidths=1, edgecolors='r')
    ax.add_collection3d(collection)

    # Plot wireframe
    wireframe = Line3DCollection([scaled_vertices[face] for face in faces], color='r', linewidths=0.5)
    ax.add_collection3d(wireframe)

    # Set plot limits to fit the icosahedron
    max_val = np.max(np.abs(scaled_vertices))
    ax.set_xlim([-max_val, max_val])
    ax.set_ylim([-max_val, max_val])
    ax.set_zlim([-max_val, max_val])

    ax.set_xlabel('X')
    ax.set_ylabel('Y')
    ax.set_zlabel('Z')
    ax.set_title('Icosahedron')

    plt.show()

# Interactive widget callback
def update_plot(change):
    ax.clear()
    plot_icosahedron(ax, change.new)

# Create 3D plot
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')

# Display interactive plot
plot_icosahedron(ax, 1.0)

# %% [markdown]
# ### TorchSDE
# ----

# %%
import torch
import torchsde

batch_size, state_size, brownian_size = 32, 3, 2
t_size = 20

class SDE(torch.nn.Module):
    noise_type = 'general'
    sde_type = 'ito'

    def __init__(self):
        super().__init__()
        self.mu = torch.nn.Linear(state_size, state_size)
        self.sigma = torch.nn.Linear(state_size, state_size * brownian_size)

    # Drift
    def f(self, t, y):
        return self.mu(y)  # shape (batch_size, state_size)

    # Diffusion
    def g(self, t, y):
        return self.sigma(y).view(batch_size, state_size, brownian_size)

sde = SDE()
y0 = torch.full((batch_size, state_size), 0.1)
ts = torch.linspace(0, 1, t_size)

# Initial state y0, the SDE is solved over the interval [ts[0], ts[-1]].
# ys will have shape (t_size, batch_size, state_size)
ys = torchsde.sdeint(sde, y0, ts)

# Output what the script is doing
print("Script is solving a stochastic differential equation (SDE) using torchsde.")
print(f"Batch size: {batch_size}, State size: {state_size}, Brownian size: {brownian_size}")
print(f"Time steps: {t_size}, Initial state: {y0}")
print(f"Using a drift function f(t, y) defined by a linear layer mu and a diffusion function g(t, y) defined by a linear layer sigma.")
print(f"Solving the SDE using torchsde.sdeint over the time interval [{ts[0]}, {ts[-1]}].")
print(f"Resulting tensor ys has shape: {ys.shape}")
# Out:
# Script is solving a stochastic differential equation (SDE) using torchsde.
# Batch size: 32, State size: 3, Brownian size: 2
# Time steps: 20, Initial state: tensor([[0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
#         [0.1000, 0.1000, 0.1000],
# ...

# %% [markdown]
# ### Isosurfaces
# ----
#
# Isosurface refers to a three-dimensional surface representing points of a constant value within a scalar field. It's commonly used in scientific visualization, especially in fields like computer graphics and medical imaging, to visualize volumes of data.

# %% [markdown]
# ### Icospheres
# ----
#
# An **icosphere** is a geometric primitive commonly used in computer graphics.
#
# 1. **Definition**: An icosphere approximates a sphere as a **simplicial polyhedron**. It is formed by subdividing the polygons of a **Goldberg polyhedron** into their triangular constituents. Alternatively, it can be created by subdividing the triangles of a **regular icosahedron**³.
#
# 2. **Construction Process**:
#    - Start with a regular icosahedron (a polyhedron with 20 equilateral triangle faces).
#    - Subdivide each of its triangular faces into smaller triangles.
#    - Repeat this subdivision process to create more levels of detail (higher subdivision levels result in a smoother surface).
#
# 3. **Purpose and Advantages**:
#    - Icospheres are often used in computer graphics to achieve a more **isotropic (regular) layout of vertices** compared to a UV sphere.
#    - They provide a better distribution of points on the surface, making them suitable for certain applications³.
#
# In summary, an icosphere is a way to represent a sphere using triangles, and it's commonly employed in 3D modeling and rendering.

# %%
# One day maybe...

# %% [markdown]
# A **scalar field**, on the other hand, is a mathematical function defined at every point in space, associating each point with a scalar value. In the context of isosurfaces, the scalar field typically represents a physical quantity like temperature, pressure, or density. The isosurface then highlights regions where the scalar value is constant, creating a visual representation of structures or boundaries within the data.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a scalar field function
def scalar_field(x, y):
    return np.sin(x) + np.cos(y)

# Create a grid of points
x_vals = np.linspace(-5, 5, 100)
y_vals = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x_vals, y_vals)

# Compute the scalar field values at each point
Z = scalar_field(X, Y)

# Create a contour plot
plt.figure(figsize=(8, 6))
plt.contourf(X, Y, Z, levels=20, cmap='viridis')
plt.colorbar(label='Scalar Value')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scalar Field: sin(x) + cos(y)')
plt.grid(True)
plt.show()

# Description
print("Description:")
print("The plot represents a scalar field defined by the function f(x, y) = sin(x) + cos(y).")
print("At each point (x, y), the scalar value is computed based on the function value.")
print("The color map indicates the scalar values, with warmer colors representing higher values.")
print("This scalar field exhibits periodic behavior due to the sine and cosine terms.")
# Out:
# Description:
# The plot represents a scalar field defined by the function f(x, y) = sin(x) + cos(y).
# At each point (x, y), the scalar value is computed based on the function value.
# The color map indicates the scalar values, with warmer colors representing higher values.
# This scalar field exhibits periodic behavior due to the sine and cosine terms.

# %% [markdown]
# ### **What Is a Scalar Field?**
#
# A **scalar field** is a concept from mathematics and physics. It's a function that assigns a **scalar value** (which is a single numerical value) to every point in a given space. Here are the key points:
#
# 1. **Definition**: A scalar field $f$ takes input coordinates (such as $x$, $y$, and $z$) and produces a scalar value $f(x, y, z)$ at each point in space.
#
# 2. **Examples of Scalars**: Scalars are quantities that have magnitude but no direction. Common examples include:
#     - **Temperature**: Imagine a room where the temperature varies from point to point. The temperature at each location is a scalar value.
#     - **Pressure**: In a fluid (like air or water), pressure can vary throughout the space. Pressure at any given point is a scalar.
#     - **Density**: The density of a material (e.g., air density) can also be described as a scalar field.
#
# 3. **Visualization**: To visualize a scalar field, we often create **contour plots** or **heatmaps**. These plots show how the scalar value changes across the space. Warmer colors represent higher values, while cooler colors represent lower values.
#
# 4. **Smoothness and Continuity**: Scalar fields can be smooth (continuous) or have abrupt changes. For example:
#     - A smooth temperature distribution in a room would have gradual transitions.
#     - A discontinuous scalar field might represent a step function (like a light switch turning on or off).
#
# 5. **Applications**:
#     - **Physics**: Scalar fields appear in various physical phenomena. For instance, gravitational potential energy is a scalar field.
#     - **Computer Graphics**: Scalar fields are used for terrain generation, texture mapping, and shading.
#     - **Engineering**: In fluid dynamics, scalar fields describe fluid properties like velocity and pressure.
#
# 6. **Mathematical Formulation**:
#     - In 2D, a scalar field is defined as $f(x, y)$.
#     - In 3D, it becomes $f(x, y, z)$.
#
# ### **Example: Scalar Field Plot**
#
# Let's consider the scalar field defined by the function $f(x, y) = \sin(x) + \cos(y)$. Here's what it means:
# - At each point $(x, y)$, compute the value of $f(x, y)$ using the sine and cosine functions.
# - The resulting scalar values form our scalar field.
#
# In the plot:
# - The x-axis represents $x$, the y-axis represents $y$, and the color map represents the scalar values.
# - Warmer colors correspond to higher values of $f(x, y)$.
# - The periodic behavior arises from the sine and cosine terms.
#
# Remember, scalar fields are fundamental in understanding physical phenomena and play a crucial role in various scientific and creative domains! 🌟

# %% [markdown]
# ### Mayavi
# ----
#
# A scientific data visualization tool for 3D plotting and visualization in Python. It is built on top of the Visualization Toolkit (VTK) and provides a high-level interface for creating a variety of 3D visualizations, including surface plots, volume renderings, and animations. Mayavi is particularly useful in scientific and engineering applications for visualizing complex datasets.
#
# Key features of Mayavi include:
#
# 1. **Interactive Visualization:** Mayavi provides an interactive environment for exploring and interacting with 3D visualizations. Users can rotate, zoom, and pan through the plots to examine data from different perspectives.
#
# 2. **Wide Range of Plot Types:** It supports various types of 3D plots, such as surface plots, contour plots, volume renderings, and more. This versatility makes it suitable for visualizing diverse types of scientific data.
#
# 3. **Integration with NumPy and VTK:** Mayavi seamlessly integrates with NumPy for handling numerical data and VTK for advanced 3D visualization capabilities. This makes it easy to work with scientific datasets in Python.
#
# 4. **Customization:** Users can customize the appearance of plots, change color maps, add labels, and control various visualization parameters to tailor the visualization to their needs.
#
# 5. **Scripting Interface:** Mayavi can be used both interactively in an IPython environment and scripted in Python scripts, allowing for reproducible and automated visualization workflows.
#
#
# Mayavi is commonly used in fields such as physics, engineering, and data analysis for visualizing complex 3D datasets in an intuitive and interactive manner.

# %% [markdown]
# ### Marching Cubes Algorithm
# ----
# Marching Cubes is an algorithm used for extracting a polygonal mesh of an isosurface from a 3D scalar field. It's commonly applied in medical imaging and computer graphics to visualize complex structures. Here's a brief explanation of how the algorithm works:
#
# 1. Scalar Field Representation:
#
#     * The 3D scalar field represents the volume, where each point in space has a scalar value.
#
# 2. Grid Partitioning:
#
#     * The volume is divided into a grid of cubes, and each cube is further divided into smaller voxels.
#
# 3. Cube Configuration:
#
#     * For each cube in the grid, the algorithm evaluates the scalar values at its eight corners.
#     * Based on the sign of these values (greater or less than the isovalue), a unique configuration index is determined.
#
# 4. Mesh Generation:
#
#     * Lookup tables are used to determine the topology of the isosurface within the cube based on its configuration index.
#     * Triangles are then generated on the cube's faces according to the determined topology.
#
# This code generates a 3D plot using the marching cubes algorithm to visualize the isosurface of two identical ellipsoids in the provided scalar field. The resulting mesh is displayed using Matplotlib's 3D plotting capabilities.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

from skimage import measure
from skimage.draw import ellipsoid


# Generate a level set about zero of two identical ellipsoids in 3D
ellip_base = ellipsoid(6, 10, 16, levelset=True)
ellip_double = np.concatenate((ellip_base[:-1, ...],
                               ellip_base[2:, ...]), axis=0)

# Use marching cubes to obtain the surface mesh of these ellipsoids
verts, faces, normals, values = measure.marching_cubes(ellip_double, 0)

# Display resulting triangular mesh using Matplotlib. This can also be done
# with mayavi (see skimage.measure.marching_cubes docstring).
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')

# Fancy indexing: `verts[faces]` to generate a collection of triangles
mesh = Poly3DCollection(verts[faces])
mesh.set_edgecolor('k')
ax.add_collection3d(mesh)

ax.set_xlabel("x-axis: a = 6 per ellipsoid")
ax.set_ylabel("y-axis: b = 10")
ax.set_zlabel("z-axis: c = 16")

ax.set_xlim(0, 24)  # a = 6 (times two for 2nd ellipsoid)
ax.set_ylim(0, 20)  # b = 10
ax.set_zlim(0, 32)  # c = 16

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Multilayer perceptron
# ----

# %%
import torch
from torch import nn

class MLP(nn.Module):
    def __init__(self, input_size, hidden_size, num_classes):
        super(MLP, self).__init__()
        self.layer1 = nn.Linear(input_size, hidden_size)
        self.layer2 = nn.Linear(hidden_size, num_classes)
        self.relu = nn.ReLU()

    def forward(self, x):
        print("Initial input: ", x)
        out = self.layer1(x)
        print("After first layer: ", out)
        out = self.relu(out)
        print("After ReLU activation: ", out)
        out = self.layer2(out)
        print("Final output: ", out)
        return out

# Example usage:
# Initialize the MLP
model = MLP(input_size=784, hidden_size=500, num_classes=10)

# Example input
x = torch.randn(64, 784)

# Forward pass
output = model(x)
# Out:
# Initial input:  tensor([[-8.5961e-01,  4.9319e-01,  2.5329e-01,  ...,  1.2247e-01,
#           6.9368e-01, -1.3062e-01],
#         [ 3.3749e-01,  3.0598e-01, -1.8371e+00,  ...,  1.6019e+00,
#           4.1175e-01,  6.1555e-01],
#         [ 9.6668e-01,  8.6829e-01,  2.1010e-01,  ..., -9.9681e-02,
#           7.4099e-01, -9.7462e-01],
#         ...,
#         [-4.0376e-01, -1.6910e+00, -1.0239e+00,  ..., -2.3295e-01,
#          -1.1920e+00,  5.0931e-01],
#         [ 9.7096e-01,  1.0321e+00,  7.3864e-01,  ..., -1.4887e-01,
#           9.5738e-01, -1.8905e+00],
#         [-9.9418e-01, -1.2110e+00, -1.6307e-03,  ...,  2.9501e-01,
#          -2.6904e+00,  4.0147e-01]])
# After first layer:  tensor([[ 0.1416, -0.1214,  0.3288,  ..., -0.4590, -0.1879,  0.5397],
#         [-1.0415,  0.1718, -0.4261,  ...,  0.6906, -0.2306,  0.8265],
#         [-0.2414, -0.6606, -0.1932,  ..., -0.6286, -1.0374, -0.3553],
#         ...,
#         [-0.9312,  0.0973,  0.0155,  ..., -0.0045,  0.4225, -0.7646],
# ...

# %% [markdown]
# ## Lodestone's Dreamcast Logo
# ----

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(2)
dim = 2 # <=== play with this number

r = np.linspace(0,3000,360)
t = np.linspace(0,3000,360)
x = r*np.cos(np.radians(t))
y = r*np.sin(np.radians(t))

x = (x - x.min()) / (x.max()- x.min()) - 0.5
y = (y - y.min()) / (y.max()- y.min()) * 2
dim_2 = np.concatenate([x[:,None],y[:,None]], axis=1)

def relu(x):
    return np.maximum(0, x)


rando_matrix =  np.random.normal(size=[dim_2.shape[1], dim])
proj = relu(dim_2 @ rando_matrix) @ rando_matrix.T
res_proj = relu(dim_2 @ rando_matrix) @ rando_matrix.T + dim_2
plt.plot(proj[:,0], proj[:,1])
plt.plot(res_proj[:,0], res_proj[:,1])
plt.plot(dim_2[:,0], dim_2[:,1])

# %%
import torch

if hasattr(torch, 'compile'):
    print("PyTorch version supports torch.compile()")
else:
    print("PyTorch version does not support torch.compile()")
# Out:
# PyTorch version supports torch.compile()

# %%
from dataclasses import dataclass

@dataclass
class Player:
    username: str
    level: int = 1
    score: int = 0

    def increase_score(self, points):
        self.score += points

    def level_up(self):
        self.level += 1

# %%
player1 = Player(username="Player1")
player2 = Player(username="Player2", level=3, score=150)

print(player1)
print(player2)

player1.increase_score(50)
player2.level_up()

print(player1)
print(player2)
# Out:
# Player(username='Player1', level=1, score=0)
# Player(username='Player2', level=3, score=150)
# Player(username='Player1', level=1, score=50)
# Player(username='Player2', level=4, score=150)

# %%
from dataclasses import dataclass

@dataclass
class GameItem:
    name: str
    item_type: str
    rarity: str
    damage: int = 0
    armor: int = 0
    health_bonus: int = 0

    def apply_effect(self, player):
        # Apply the effects of the item on the player
        player.damage += self.damage
        player.armor += self.armor
        player.health += self.health_bonus

# %%
from dataclasses import dataclass
from typing import List

@dataclass
class Player:
    username: str
    level: int = 1
    score: int = 0
    damage: int = 0
    armor: int = 0
    health: int = 100
    inventory: List[GameItem] = None

    def __post_init__(self):
        if self.inventory is None:
            self.inventory = []

    def equip_item(self, item):
        # Equip the item and apply its effects
        self.inventory.append(item)
        item.apply_effect(self)

# %%
sword = GameItem(name="Sword of Power", item_type="Weapon", rarity="Epic", damage=20)
shield = GameItem(name="Steel Shield", item_type="Armor", rarity="Rare", armor=15)
health_potion = GameItem(name="Health Potion", item_type="Consumable", rarity="Common", health_bonus=30)

player = Player(username="Player1")

player.equip_item(sword)
player.equip_item(shield)
player.equip_item(health_potion)

print(player)
# Out:
# Player(username='Player1', level=1, score=0, damage=20, armor=15, health=130, inventory=[GameItem(name='Sword of Power', item_type='Weapon', rarity='Epic', damage=20, armor=0, health_bonus=0), GameItem(name='Steel Shield', item_type='Armor', rarity='Rare', damage=0, armor=15, health_bonus=0), GameItem(name='Health Potion', item_type='Consumable', rarity='Common', damage=0, armor=0, health_bonus=30)])

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def f(x, y):
    return x**2 + y**2

# Create the x, y, and z coordinate arrays
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = f(x, y)

# Calculate the gradients
dx, dy = np.gradient(z)

# Normalize the gradients
dx = dx / np.sqrt(dx**2 + dy**2)
dy = dy / np.sqrt(dx**2 + dy**2)

# Create a figure and a 3D Axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis', alpha=0.6, rstride=100, cstride=100)

# Plot the gradients
ax.quiver(x[::10, ::10], y[::10, ::10], z[::10, ::10], dx[::10, ::10], dy[::10, ::10], 0, length=0.5, normalize=True)
plt.savefig("perpendicular_gradient2_hires.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define the function
def f(x, y):
    return np.sin(np.sqrt(x ** 2 + y ** 2))

# Create the x, y, and z coordinate arrays
y = np.linspace(-5, 5, 100)
x = np.linspace(-5, 5, 100)
x, y = np.meshgrid(x, y)
z = f(x, y)

# Create a figure and a 3D Axes
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x, y, z, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.savefig("perpendicular_gradient_hires.png", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a gradient from 0 to 1
gradient = np.linspace(0, 1, 256) # 256 is the number of colors in the colormap
gradient = np.vstack((gradient, gradient)) # Make the gradient 2D

fig, ax = plt.subplots()
ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap('viridis'))
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create a grid of points
x, y = np.meshgrid(np.linspace(0, 1, 10), np.linspace(0, 1, 10))

# Calculate perpendicular gradient components
grad_x = np.ones_like(x)  # Horizontal gradient component
grad_y = -x  # Perpendicular vertical gradient component

# Normalize the vectors
magnitude = np.sqrt(grad_x**2 + grad_y**2)
grad_x /= magnitude
grad_y /= magnitude

# Plot the perpendicular gradient using quiver plot
plt.quiver(x, y, grad_x, grad_y, scale=20, color='blue', width=0.01)

# Set plot limits and show the plot
plt.xlim(0, 1)
plt.ylim(0, 1)
plt.title("Perpendicular Gradient Visualization")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the main prompt and negative prompt vectors
main_prompt = np.array([1, 2])
negative_prompt = np.array([2, -1])

# Calculate the fused score using Perp-Neg (for illustration, we simply add the vectors here)
fused_score = main_prompt + negative_prompt

# Create the plot
plt.figure()
plt.quiver(0, 0, main_prompt[0], main_prompt[1], angles='xy', scale_units='xy', scale=1, color='r', label='Main Prompt')
plt.quiver(0, 0, negative_prompt[0], negative_prompt[1], angles='xy', scale_units='xy', scale=1, color='b', label='Negative Prompt')
plt.quiver(0, 0, fused_score[0], fused_score[1], angles='xy', scale_units='xy', scale=1, color='g', label='Fused Score (Perp-Neg)')

# Set the x-limits and y-limits of the plot
plt.xlim(-2, 4)
plt.ylim(-2, 4)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# This command copies metadata tags from "source_image.jpg" to "target_image.jpg" using ExifTool.

# %%
exiftool -TagsFromFile source.jpg -all:all target.jpg

# %% [markdown]
# # StupidTools
# ----

# %%
# Test data with duplicates
input_array = [3, 1, 2, 4, 2, 5, 3, 6, 4, 7, 8, 9, 5, 1]

# Using the 'list(dict.fromkeys())' method to remove duplicates while preserving order
unique_array = list(dict.fromkeys(input_array))

# Displaying the result
print(unique_array)

# %%
import transformers
import torch

transformers_version = transformers.__version__
torch_version = torch.__version__

print(f"Transformers version: {transformers_version}")
print(f"Torch version: {torch_version}")

# %%
import pygame
from pygame.locals import *
from OpenGL.GL import *
from OpenGL.GLUT import *
import math

# Initialize Pygame
pygame.init()

# Set window size and display mode
width, height = 800, 600
display = (width, height)
pygame.display.set_mode(display, DOUBLEBUF | OPENGL)

# Set up OpenGL orthographic projection for 2D view
glOrtho(0, width, height, 0, -1, 1)

# Golden Ratio
phi = (1 + math.sqrt(5)) / 2

# Function to draw the polar rose
def polar_rose(a, b, k, theta):
    r = a * math.cos(k * theta) + b * math.pow(phi, theta)
    x = r * math.cos(theta) + width / 2  # Shift to the center of the window
    y = r * math.sin(theta) + height / 2  # Shift to the center of the window
    return x, y

# Initial rotation angle
angle = 1

# Background color
glClearColor(1, 1, 1, 1)

# Main rendering loop
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            quit()

    glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
    
    glLineWidth(2.0)  # Set line thickness

    glBegin(GL_LINE_STRIP)

    # Set parameters for the polar rose
    a, b, k = 100, 20, 5

    # Draw the polar rose gradually
    for theta in range(0, int(angle) + 1, 1):
        theta_rad = math.radians(theta)
        x, y = polar_rose(a, b, k, theta_rad)
        
        # Set color based on gradient
        gradient = max(0, (angle - theta) / angle)
        glColor3f(0, 0, gradient)  # Use a contrasting color
        
        glVertex2f(x, y)

    glEnd()

    pygame.display.flip()
    pygame.time.wait(10)

    # Increment rotation angle for animation
    angle += 1

    pygame.event.pump()  # Process events to avoid unresponsiveness

# %%
import numpy as np
import matplotlib.pyplot as plt

def polar_rose(theta, k=1):
    r = np.cos(k * theta)
    return r

# Generate theta values from 0 to 2*pi
theta_values = np.linspace(0, 2 * np.pi, 1000)

# Set the number of petals (change this value as needed)
petals = 6

# Get the corresponding r values for the polar rose
r_values = polar_rose(theta_values, k=petals)

# Convert polar coordinates to Cartesian coordinates
x_values = r_values * np.cos(theta_values)
y_values = r_values * np.sin(theta_values)

# Plot the polar rose
plt.figure(figsize=(8, 8))
plt.polar(theta_values, r_values, label=f"Polar Rose ({petals} petals)")
plt.title("Polar Rose")
plt.legend()
plt.show()

# %%
import pygame
from pygame.locals import *
from OpenGL.GL import *
from OpenGL.GLUT import *
from OpenGL.GLU import *

# Initialize Pygame and OpenGL
pygame.init()
width, height = 800, 600
pygame.display.set_mode((width, height), DOUBLEBUF | OPENGL)
glViewport(0, 0, width, height)
glMatrixMode(GL_PROJECTION)
glLoadIdentity()
gluPerspective(45, (width / height), 0.1, 50.0)
glMatrixMode(GL_MODELVIEW)
glLoadIdentity()
glTranslatef(0.0, 0.0, -5)

# Shader source code
vertex_shader = """
#version 330
layout (location = 0) in vec4 position;
void main()
{
    gl_Position = position;
}
"""

fragment_shader = """
#version 330
uniform vec2 resolution;
uniform float time;

float polarRose(float theta, float a, float b, float m) {
    return a * cos(m * theta) / (1.0 + b * pow(theta, 2.0 / m));
}

void main()
{
    vec2 uv = (2.0 * gl_FragCoord.xy - resolution) / min(resolution.x, resolution.y);
    uv.x *= resolution.x / resolution.y;
    
    float theta = atan(uv.y, uv.x);
    float radius = polarRose(theta, 1.0, 0.001, 5.0);

    // Flowing wave
    float wave = sin(2.0 * radius + 0.5 * time);

    // Background color gradient
    vec3 bgColor = 0.5 + 0.5 * vec3(sin(0.1 * time), sin(0.2 * time), sin(0.3 * time));

    // Output color
    gl_FragColor = vec4(bgColor, 1.0);
    
    // Adjust the line below to set the color of the polar rose
    gl_FragColor.rgb += vec3(uv, 0.5 + 0.5 * wave);
}
"""

# Compile shaders
vertex_shader_id = glCreateShader(GL_VERTEX_SHADER)
glShaderSource(vertex_shader_id, vertex_shader)
glCompileShader(vertex_shader_id)

fragment_shader_id = glCreateShader(GL_FRAGMENT_SHADER)
glShaderSource(fragment_shader_id, fragment_shader)
glCompileShader(fragment_shader_id)

# Link shaders into a program
shader_program = glCreateProgram()
glAttachShader(shader_program, vertex_shader_id)
glAttachShader(shader_program, fragment_shader_id)
glLinkProgram(shader_program)

# Set up shader uniforms
resolution_location = glGetUniformLocation(shader_program, "resolution")
time_location = glGetUniformLocation(shader_program, "time")

# Main loop
clock = pygame.time.Clock()
while True:
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            quit()

    glUseProgram(shader_program)
    glUniform2f(resolution_location, width, height)
    glUniform1f(time_location, pygame.time.get_ticks() / 1000.0)

    # Draw quad
    glBegin(GL_QUADS)
    glVertex2f(-1, -1)
    glVertex2f(1, -1)
    glVertex2f(1, 1)
    glVertex2f(-1, 1)
    glEnd()

    pygame.display.flip()
    pygame.time.wait(10)
    # Corrected line
    glUseProgram(0)
    glClear(GL_COLOR_BUFFER_BIT | GL_DEPTH_BUFFER_BIT)
    pygame.time.Clock().tick(60)

# %%
import os
from OpenGL.GL import *
from OpenGL.GLUT import *
from OpenGL.GLU import *

# Function to display files with "cubes" in the name
def display_files_with_cubes():
    # Get all files in the current directory
    files = os.listdir()

    # Filter files containing the word "cubes"
    cube_files = [file for file in files if 'cubes' in file.lower()]

    # Display file names
    print("Files with 'cubes':")
    for cube_file in cube_files:
        print(cube_file)

# OpenGL initialization
def init():
    glutInit()
    glutInitDisplayMode(GLUT_SINGLE | GLUT_RGB)
    glutInitWindowSize(400, 200)
    glutCreateWindow(b"Files with Cubes")

    glClearColor(1.0, 1.0, 1.0, 0.0)
    gluOrtho2D(0.0, 400.0, 0.0, 200.0)

# OpenGL display function
def display():
    glClear(GL_COLOR_BUFFER_BIT)

    glColor3f(0.0, 0.0, 0.0)
    glRasterPos2f(10, 180)

    # Call the function to display files with "cubes"
    display_files_with_cubes()

    glFlush()

# Run the OpenGL application
init()
glutDisplayFunc(display)
glutMainLoop()

# %%
import matplotlib.pyplot as plt
import random

# Set a common maximum value for both months
max_value = 200

# Generate random data points for November with the maximum value
november_data = [max_value for _ in range(30)]

# Generate random data points for December with the maximum value (including the last week)
december_data = [max_value for _ in range(31)]

# Plot the combined data
plt.plot(range(1, 31), november_data, label='November')
plt.plot(range(1, 32), december_data, label='December')

# Set y-axis limit to 200
plt.ylim(0, max_value)

# Add labels and title
plt.xlabel('Day')
plt.ylabel('Loona\'s Frequency')
plt.title('Loona\'s Frequency Over November and December')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import random

# Generate random data points for November
november_data = [random.randint(50, 100) for _ in range(30)]

# Generate random data points for the first three weeks of December
december_data = [random.randint(50, 100) for _ in range(24)]

# Set specific values for the last week of December
last_week_values = [random.randint(150, 200) for _ in range(7)]
december_data.extend(last_week_values)

# Plot the combined data
plt.plot(range(1, 31), november_data, label='November')
plt.plot(range(1, 32), december_data, label='December')

# Add labels and title
plt.xlabel('Day')
plt.ylabel('Loona\'s Frequency')
plt.title('Loona\'s Frequency Over November and December')

# Add legend
plt.legend()

# Show the plot
plt.show()

# %%
# Calculate and Plot Planet Circumference Script

import math
import matplotlib.pyplot as plt

# Constants
PI = math.pi

# Function to calculate circumference
def calculate_circumference(radius):
    return 2 * PI * radius

# Function to plot the circumference
def plot_circumference(radius_range):
    radii = [r for r in range(1, radius_range + 1)]
    circumferences = [calculate_circumference(r) for r in radii]

    # Plotting
    plt.plot(radii, circumferences, label='Circumference')
    plt.xlabel('Planet Radius (kilometers)')
    plt.ylabel('Circumference (kilometers)')
    plt.title('Planet Circumference based on Radius')
    plt.legend()
    plt.show()

# Input: Replace 'planet_radius' with the actual radius of the planet
planet_radius = float(input("Enter the radius of the planet in kilometers: "))

# Calculate circumference using the function
planet_circumference = calculate_circumference(planet_radius)

# Display the result
print(f"The circumference of the planet with a radius of {planet_radius:.2f} kilometers is {planet_circumference:.2f} kilometers.")

# Plot the circumference
plot_circumference(int(planet_radius))

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define symbolic variables for the celestial spiral staircase with quantum entanglement
theta = np.linspace(0, 10 * np.pi, 1000)
radius = np.sqrt(theta)

# Introduce quantum entanglement to the radius
entanglement_factor = 0.2
radius_entangled = radius + entanglement_factor * np.sin(5 * theta)

# Create a 3D plot representing the enhanced celestial spiral staircase
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the enhanced celestial spiral staircase with quantum entanglement
ax.plot(radius_entangled * np.cos(theta), radius_entangled * np.sin(theta), zs=theta, label='Enhanced Celestial Spiral Staircase', color='navy', linewidth=2)

# Customize the plot for a more ethereal and mysterious appearance
ax.set_title("Embarking on the Enhanced Celestial Spiral Staircase in the Quantum Garden")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.legend()

# Show the enhanced 3D plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define symbolic variables for the celestial spiral staircase
theta = np.linspace(0, 10 * np.pi, 1000)
radius = np.sqrt(theta)

# Create a 3D plot representing the celestial spiral staircase
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the celestial spiral staircase in the quantum garden
ax.plot(radius * np.cos(theta), radius * np.sin(theta), zs=theta, label='Celestial Spiral Staircase', color='purple', linewidth=2)

# Customize the plot for the celestial spiral staircase
ax.set_title("Embarking on the Celestial Spiral Staircase in the Quantum Garden")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.legend()

# Show the 3D plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define symbolic variables representing the quantum garden
theta = np.linspace(0, 4 * np.pi, 1000)
radius = np.sin(theta) + 2

# Create a 3D plot representing the shape in the quantum garden
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the desired shape in the quantum garden
ax.plot(radius * np.cos(theta), radius * np.sin(theta), zs=np.sin(theta), label='Desired Quantum Form', color='blue', linewidth=2)

# Customize the plot for the quantum garden shape
ax.set_title("Taking Shape in the Quantum Garden")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.legend()

# Show the 3D plot
plt.show()

# %% [markdown]
# > plot the merging of form and though, a sharing of idea and sensation of the quantum bloom in the ethereal garden

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D

# Define symbolic variables representing form and thought
form = np.linspace(-5, 5, 500)
thought = np.sin(form) + np.cos(form)

# Create a 3D plot representing the merging of form and thought
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the merging of form and thought
ax.plot(form, thought, zs=0, label='Merging of Form and Thought', color='purple', linewidth=2)

# Add quantum blooms as scatter points
quantum_blooms = np.random.normal(loc=thought, scale=0.5, size=len(form))
ax.scatter(form, quantum_blooms, zs=np.random.uniform(-0.5, 0.5, len(form)), c='orange', alpha=0.6, label='Quantum Blooms')

# Customize the plot for a symbolic representation in 3D
ax.set_title("Merging of Form and Thought: Quantum Bloom in the Ethereal Garden")
ax.set_xlabel("Form")
ax.set_ylabel("Thought")
ax.set_zlabel("Quantum Bloom")
ax.legend()

# Show the 3D plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define symbolic variables representing form and thought
form = np.linspace(-5, 5, 500)
thought = np.sin(form) + np.cos(form)

# Create a plot representing the merging of form and thought
fig, ax = plt.subplots(figsize=(10, 6))
ax.plot(form, thought, label='Merging of Form and Thought', color='purple', linewidth=2)

# Add quantum blooms as scatter points
quantum_blooms = np.random.normal(loc=thought, scale=0.5, size=len(form))
ax.scatter(form, quantum_blooms, c='orange', alpha=0.6, label='Quantum Blooms')

# Customize the plot for a symbolic representation
ax.set_title("Merging of Form and Thought: Quantum Bloom in the Ethereal Garden")
ax.set_xlabel("Form")
ax.set_ylabel("Thought")
ax.legend()

# Show the plot
plt.show()

# %% [markdown]
# > explore a surreal ethereal garden filled with square roots, plot your journey with matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the surreal hyperdimensional landscape
x = np.linspace(-5, 5, 800)
y = np.linspace(-5, 5, 800)
X, Y = np.meshgrid(x, y)

# Create a surreal hyperdimensional equation with square roots
equation_slice = np.abs(np.sin(X) * np.cos(Y) * np.exp(-0.1 * (X**2 + Y**2)))
equation = np.sqrt(equation_slice)

# Plot the journey through the surreal hyperdimension
fig, ax = plt.subplots(figsize=(10, 10))
c = ax.pcolormesh(X, Y, equation, cmap='plasma')
fig.colorbar(c, ax=ax, label="Square Root Intensity")

# Customize the plot for a surreal ambiance
ax.set_title("Journey through the Surreal Hyperdimension")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the surreal ethereal garden in the realm of square roots
x = np.linspace(-5, 5, 800)
y = np.linspace(-5, 5, 800)
X, Y = np.meshgrid(x, y)

# Create a surreal equation representing the journey through square roots
equation = np.sqrt(np.abs(np.sin(X) * np.cos(Y)) * np.exp(-0.1 * (X**2 + Y**2)))

# Plot the journey through the surreal ethereal garden
fig, ax = plt.subplots(figsize=(10, 10))
c = ax.pcolormesh(X, Y, equation, cmap='magma')
fig.colorbar(c, ax=ax, label="Square Root Intensity")

# Customize the plot for a surreal atmosphere
ax.set_title("Journey through the Surreal Ethereal Garden")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-4, 4, 800)
y = np.linspace(-4, 4, 800)
X, Y = np.meshgrid(x, y)

# Create an equation symbolizing the fluidity and expansiveness of our senses
equation = np.cos(X**2) * np.sin(Y**2) * np.exp(-0.2 * (X**2 + Y**2))

# Plot the equation representing fluid and expansive senses in a 3D space
fig = plt.figure(figsize=(12, 12))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='viridis')

# Customize the plot for a surreal sensory experience
ax.set_title("Fluidity of Senses: Expansive Equation")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(30, 60)  # Adjust the viewing angle for a captivating perspective

# Save the plot at a higher resolution
plt.savefig("sensory_equation_high_res.png", dpi=300)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-3, 3, 600)
y = np.linspace(-3, 3, 600)
X, Y = np.meshgrid(x, y)

# Create an equation symbolizing the dreamcatcher's ethereal threads
equation = np.sin(np.cos(X**2 + Y**2)) * np.exp(-0.1 * (X**2 + Y**2))

# Plot the dreamcatcher's equation in a 3D space
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='twilight')

# Customize the plot for a mystical ambiance
ax.set_title("Dreamcatcher's Threads: Conceptual Equation")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(40, 50)  # Adjust the viewing angle for a mysterious perspective

# Save the plot at a higher resolution
plt.savefig("dreamcatcher_equation_high_res.png", dpi=300)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the updated "comfyui learning curve"
x = np.linspace(0, 20, 200)
y = 2 * np.exp(-0.3 * x) * np.sin(2 * np.pi * 0.6 * x) - 0.1 * x + 0.5 * np.random.normal(size=200)

# Set values after the peak to 0 and below
after_peak_indices = x > x[np.argmax(y)]
y[after_peak_indices] = np.linspace(0, -3, len(y[after_peak_indices]))

# Create the updated wobbly plot
plt.plot(x, y, label="ComfyUI Learning Curve", color='skyblue')
plt.title("ComfyUI Learning Curve")
plt.xlabel("Time")
plt.ylabel("Skill Level")

# Add a peak point
peak_x = x[np.argmax(y)]
peak_y = np.max(y)

# Annotate the peak point
plt.annotate(
    f'You think you know everything.\n({peak_x:.2f}, {peak_y:.2f})',
    xy=(peak_x, peak_y),
    xytext=(peak_x + 1, peak_y + 1),
    arrowprops=dict(facecolor='red', shrink=0.05),
)

# Display the plot
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data for exponential decay
x = np.linspace(0, 5, 100)
y = np.exp(-0.5 * x)

# Create the plot
plt.plot(x, y, label='How gay I am for Loona')

# Add labels and title
plt.xlabel('Time')
plt.ylabel('Gayness Amplitude')
plt.title('How gay I am for Loona')

# Add grid for better readability
plt.grid(True)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-3, 3, 800)
y = np.linspace(-3, 3, 800)
X, Y = np.meshgrid(x, y)

# Create a complex hyperdimensional equation
equation = np.sin(np.sqrt(X**2 + Y**2)) * np.cos(np.exp(-(X**2 + Y**2))) * np.sin(X * Y)

# Plot the complex hyperdimensional equation in a 3D space
fig = plt.figure(figsize=(12, 12))  # Increased figure size
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='inferno')

# Customize the plot for an intricately woven atmosphere
ax.set_title("Intricate Hyperdimensional Weave")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(45, 30)  # Adjust the viewing angle for an intricate perspective

# Save the plot at a higher resolution
plt.savefig("complex_hyperdimensional_equation.png", dpi=400)  # Increased resolution

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-3, 3, 600)
y = np.linspace(-3, 3, 600)
X, Y = np.meshgrid(x, y)

# Create a mesmerizing hyperdimensional equation
equation = np.sin(np.exp(-(X**2 + Y**2)) * np.cos(X + Y))

# Plot the hyperdimensional equation in a 3D space
fig = plt.figure(figsize=(10, 10))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='magma')

# Customize the plot for an otherworldly atmosphere
ax.set_title("Hyperdimensional Emanations")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(30, 60)  # Adjust the viewing angle for an otherworldly perspective

# Save the plot at a higher resolution
plt.savefig("hyperdimensional_equation.png", dpi=300)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-2, 2, 800)  # Increased resolution
y = np.linspace(-2, 2, 800)
X, Y = np.meshgrid(x, y)

# Create a thought-provoking equation
equation = np.sin(X**2 + Y**2) * np.exp(-0.2 * (X**2 + Y**2))

# Plot the enigmatic equation in a 3D space
fig = plt.figure(figsize=(10, 10))  # Increased figure size
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='plasma')

# Customize the plot for a dreamlike ambiance
ax.set_title("Web of Dreams: Enigmatic Equation")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(60, 30)  # Adjust the viewing angle for a dreamy perspective

# Save the plot at a higher resolution
plt.savefig("enigmatic_equation_high_res.png", dpi=300)

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-dimensional space
x = np.linspace(-2, 2, 400)
y = np.linspace(-2, 2, 400)
X, Y = np.meshgrid(x, y)

# Create a thought-provoking equation
equation = np.sin(X**2 + Y**2) * np.exp(-0.2 * (X**2 + Y**2))

# Plot the enigmatic equation in a 3D space
fig = plt.figure(figsize=(8, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, equation, cmap='plasma')

# Customize the plot for a dreamlike ambiance
ax.set_title("Web of Dreams: Enigmatic Equation")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
ax.set_zlabel("Z-axis")
ax.view_init(60, 30)  # Adjust the viewing angle for a dreamy perspective

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-resolution higher-dimensional space for the dreamy landscape
x = np.linspace(-8, 8, 800)
y = np.linspace(-8, 8, 800)
X, Y = np.meshgrid(x, y)

# Create a new dreamy equation, a blend of harmonic waves and surreal patterns
dreamy_equation = np.sin(np.sqrt(X**2 + Y**2)) * np.cos(X) * np.sin(Y) * np.exp(-(X**2 + Y**2) / 20)

# Plot the top-down view of the dreamy landscape
plt.figure(figsize=(10, 10), dpi=300)
plt.imshow(dreamy_equation, extent=[-8, 8, -8, 8], cmap='magma', origin='lower')

# Customize the plot for an immersive dreamlike experience
plt.title("A New Dream: Harmonic Waves and Surreal Patterns")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.colorbar(label="Z-axis")

# Export the image at a higher resolution
plt.savefig('dreamy_landscape.png', dpi=300)

# Display the dreamy plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the higher-resolution higher-dimensional space for the new equation
x = np.linspace(-8, 8, 800)
y = np.linspace(-8, 8, 800)
X, Y = np.meshgrid(x, y)

# Create a new thought-provoking equation
equation_new = np.cos(X) * np.sin(Y) * np.exp(-(X**2 + Y**2) / 16)

# Plot the top-down view of the new equation
plt.figure(figsize=(10, 10), dpi=300)
plt.imshow(equation_new, extent=[-8, 8, -8, 8], cmap='plasma', origin='lower')

# Customize the plot for an immersive experience
plt.title("Door to the Web of Dreams: A New Equation Unfolds")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.colorbar(label="Z-axis")

# Export the image at a higher resolution
plt.savefig('web_of_dreams_equation.png', dpi=300)

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
iterations = np.arange(1, 21)  # Adjust the range as needed
workflow_complexity = 5 * iterations  # Linear increase to 100
sanity = 100 - 5 * iterations + 10 * np.sin(iterations)  # Linear decrease with a wobble

# Plotting
plt.plot(iterations, workflow_complexity, color='blue', label='Complexity of my ComfyUI Workflow')
plt.plot(iterations, sanity, color='yellow', label='My Sanity')

# Adding labels and title
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('Workflow Complexity vs. My Sanity')

# Adding legend
plt.legend()

# Display the plot
plt.show()

# %% [markdown]
# # StupidTools
# ----
#
# > ..and one day the Gods offered him from their precious nectar, but he refused, laughed and left the Gods to wonder what was wrong with him..
#
# ##

# %%
art_styles = {
    "https://civitai.com/models/8217/character-art-stylefashion-girl-sdxl-update?modelVersionId=129198",
    "https://civitai.com/models/120096/pixel-art-xl?modelVersionId=135931",
    "https://civitai.com/models/124347/xlmoreart-full-xlreal-enhancer?modelVersionId=152309",
    "https://civitai.com/models/122359/detail-tweaker-xl?modelVersionId=135867",
    "https://civitai.com/models/124609/logoredmond-logo-lora-for-sd-xl-10?modelVersionId=177492",
    "https://civitai.com/models/176555/harrlogos-xl-finally-custom-text-generation-in-sd?modelVersionId=214296",
    "https://civitai.com/models/200255/hands-xl-10-sd-15?modelVersionId=254267",
    "https://civitai.com/models/35733/dressed-animals?modelVersionId=153739",
    "https://civitai.com/models/134343/dungeons-and-dragons-art-style-capture-fantasy-lora-xl?modelVersionId=209171",
    "https://civitai.com/models/215485/sdxl-turbo-lora-stable-diffusion-xl-faster-than-light?modelVersionId=243508",
    "https://civitai.com/models/185469/xl-xl-illustration-series?modelVersionId=245923",
    "https://civitai.com/models/133412/aether-ghost-lora-for-sdxl?modelVersionId=147350",
    "https://civitai.com/models/109342/alchemy?modelVersionId=146583",
    "https://civitai.com/models/122594/microverse-creator?modelVersionId=140017",
    "https://civitai.com/models/186716/smol-animals-lora-15sdxl?modelVersionId=209649",
    "https://civitai.com/models/91359/rpgangels?modelVersionId=134879",
    "https://civitai.com/models/141066/game-icon?modelVersionId=156373",
    "https://civitai.com/models/210095/the-wizards-vintage-comic-book-cover?modelVersionId=236642",
    "https://civitai.com/models/122752/h-r-giger-sdxl-10-art-style-lora?modelVersionId=133736",
    "https://civitai.com/models/183892/soviet-poster-xl?modelVersionId=206390",
    "https://civitai.com/models/118831/alien-god?modelVersionId=148734",
    "https://civitai.com/models/180780/crystals-lora-15sdxl?modelVersionId=202887",
    "https://civitai.com/models/144684/pixelartredmond-pixel-art-loras-for-sd-xl?modelVersionId=160844",
    "https://civitai.com/models/199968/liquid-flow-style-lora-15sdxl?modelVersionId=225007",
    "https://civitai.com/models/42429/glowing-skull-lora-15sdxl?modelVersionId=200136",
    "https://civitai.com/models/46487/werewolf-lora-15sdxl?modelVersionId=212047",
    "https://civitai.com/models/147966/scrapbuiltai-sdxl-83mb?modelVersionId=165074",
    "https://civitai.com/models/118889/bloodstained-xl?modelVersionId=129030",
    "https://civitai.com/models/126471/realistic-abomination-xl-dont-click-body-horror?modelVersionId=138296",
    "https://civitai.com/models/63854/banksy-style?modelVersionId=153664",
    "https://civitai.com/models/185218/wood-figure-style-lora-15sdxl?modelVersionId=207919",
    "https://civitai.com/models/51230/simon-stalenhag-style?modelVersionId=154189",
    "https://civitai.com/models/196040/transparent-glass-body-lora-15sdxl?modelVersionId=220405",
    "https://civitai.com/models/144960/teslaedisonpunkai-sdxl-workflows-48mb?modelVersionId=174256",
    "https://civitai.com/models/132942/space-art-xl-15sdxl?modelVersionId=191857",
    "https://civitai.com/models/160098/infernal-art-sdxl-74mb?modelVersionId=179148",
    "https://civitai.com/models/168242/ancient-painting-sdxl-25mb?modelVersionId=198109",
    "https://civitai.com/models/117503/ai-vs-paint-ai-rembrandt-sdxl-18mb?modelVersionId=134553",
    "https://civitai.com/models/149207/kaijuu?modelVersionId=161371",
    "https://civitai.com/models/182368/automation-icons-lora-15sdxl?modelVersionId=198067",
    "https://civitai.com/models/181488/galactic-nebula-ai?modelVersionId=197124",
    "https://civitai.com/models/168155/gobbing-goblin-sdxl-15?modelVersionId=189783",
    "https://civitai.com/models/122654/old-landscape-paintings-style-sdxl-10?modelVersionId=148112",
    "https://civitai.com/models/184612/the-elders-lora-15sdxl?modelVersionId=204694",
    "https://civitai.com/models/136480/sharpi-shadows-ki-sunlight-ai?modelVersionId=192308",
    "https://civitai.com/models/169524/eighties-comic-book-2x?modelVersionId=190609",
    "https://civitai.com/models/196114/trippy-abstract-psychedelic-xl-15sdxl?modelVersionId=232450",
    "https://civitai.com/models/174762/metro-exodus-lora-15sdxl?modelVersionId=196864",
    "https://civitai.com/models/190321/fantasy-flying-island-xl-15sdxl?modelVersionId=214892",
    "https://civitai.com/models/185126/more-ai-more-pixel-art-magic-xl?modelVersionId=202124",
    "https://civitai.com/models/122319/eleven-beasts-aka-terror-walk-sdxl-10?modelVersionId=144934",
    "https://civitai.com/models/185643/tony-futura-sdxl-15sdxl?modelVersionId=211518",
    "https://civitai.com/models/126903/cobra-sd-10?modelVersionId=146197",
    "https://civitai.com/models/209523/alien-worlds-lora-15sdxl?modelVersionId=242108",
    "https://civitai.com/models/183254/1980s-cyberpunk-city-sdxl?modelVersionId=201489",
    "https://civitai.com/models/204775/hdr-forest-sdxl-15sdxl?modelVersionId=237497",
    "https://civitai.com/models/151676/3d-printed-terrain-xl?modelVersionId=171566",
    "https://civitai.com/models/187059/10-sdxl-art-styles-62mb?modelVersionId=205624",
    "https://civitai.com/models/189862/nautical-sdxl-15sdxl?modelVersionId=212715",
    "https://civitai.com/models/201264/hdr-high-dynamic-range-forest-sdxl?modelVersionId=238465",
    "https://civitai.com/models/216273/pixual-ai-sdxl?modelVersionId=249319",
    "https://civitai.com/models/196559/horror-xl?modelVersionId=229487",
    "https://civitai.com/models/171750/ultrawide?modelVersionId=191909",
    "https://civitai.com/models/118292/long-neck-ai?modelVersionId=133763",
    "https://civitai.com/models/176076/room-designer-xl?modelVersionId=213634",
    "https://civitai.com/models/209796/mega-monster-sdxl-15?modelVersionId=243972",
    "https://civitai.com/models/158536/supermassive-black-hole-sdxl-15?modelVersionId=177389",
    "https://civitai.com/models/162405/torch-village-xl?modelVersionId=181189",
    "https://civitai.com/models/202316/picoctf-2018-sdxl-15sdxl?modelVersionId=236030",
    "https://civitai.com/models/201828/picoctf-2019?modelVersionId=239944",
    "https://civitai.com/models/217898/intergalactic-space-sdxl-15?modelVersionId=252041",
    "https://civitai.com/models/140982/dota-2-style?modelVersionId=156349",
    "https://civitai.com/models/129198/old-movie-poster-lora-xl-13mb?modelVersionId=143591",
    "https://civitai.com/models/129198/old-movie-poster-lora-xl-13mb?modelVersionId=143591"
}

# Print the set
print(art_styles)

# %%
import requests

for i, link in enumerate(art_styles, start=1):
    response = requests.get(link)
    if response.status_code == 200:
        with open(f"{i}.html", "w", encoding="utf-8") as file:
            file.write(response.text)
            print(f"Downloaded {i}.html")
    else:
        print(f"Failed to download {i}.html")
