# %% [markdown]
# ## Tag Counter
# ----
#
# This Python script extracts tags from `.txt` files within a specified directory and its subdirectories. It then counts the frequency of each tag and lists them in descending order of frequency.

# %%
import os
from collections import Counter
from rich.console import Console
from rich.table import Table

def extract_tags_from_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()
        tags = content.split(', ')
        return tags

def process_directory(directory_path):
    all_tags = []
    for root, dirs, files in os.walk(directory_path):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                tags = extract_tags_from_file(file_path)
                all_tags.extend(tags)
    return all_tags

def list_tags_frequency(tags):
    tag_counter = Counter(tags)
    sorted_tags = sorted(tag_counter.items(), key=lambda x: x[1], reverse=True)
    return sorted_tags

directory_path = r'C:\Users\kade\Desktop\training_dir_staging'
all_tags = process_directory(directory_path)
sorted_tags = list_tags_frequency(all_tags)

# Create a Rich Table
table = Table(title="Tag Frequency")

# Add columns to the table
num_columns = 2
column_width = int(len(sorted_tags) / num_columns)
for i in range(num_columns):
    table.add_column(f"Tag ({i+1})", justify="left", style="cyan", no_wrap=False)
    table.add_column(f"Frequency", justify="center", style="magenta")

# Add rows to the table
for i in range(column_width):
    row_data = []
    for j in range(num_columns):
        index = i + j * column_width
        if index < len(sorted_tags):
            tag, frequency = sorted_tags[index]
            row_data.extend([tag, str(frequency)])
        else:
            row_data.extend(["", ""])
    table.add_row(*row_data)

# Print the table
console = Console()
console.print(table)
# Out:
#                                                    Tag Frequency
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━┓
# ┃ Tag (1)                                    ┃ Frequency ┃ Tag (2)                                    ┃ Frequency ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━┩
# │ furry sticker                              │    307    │ tight clothing                             │     1     │
# │ mammal                                     │    303    │ handwear                                   │     1     │
# │ simple background                          │    300    │ bodysuit                                   │     1     │
# │ rating_safe                                │    297    │ rubber clothing                            │     1     │
# │ fur                                        │    296    │ latex                                      │     1     │
# │ anthro                                     │    292    │ gloves                                     │     1     │
# │ male                                       │    276    │ rubber suit                                │     1     │
# │ solo                                       │    272    │ glistening                                 │     1     │
# │ transparent background                     │    219    │ This image is a sticker of two anthro      │     1     │
# │                                            │           │ characters.                                │           │
# │ canid                                      │    188    │ A tiger is standing upright wearing a cap  │     1     │
# │                                            │           │ with an American flag and holding an       │           │
# │                                            │           │ anthro fox around its arms and holding a   │           │
# │                                            │           │ black mask in front of the fox's face.     │           │
# │ canine                                     │    186    │ The tiger is also wearing a black and      │     1     │
# │                                            │           │ orange outfit.                             │           │
# │ white body                                 │    164    │ Above them there's a speech bubble with    │     1     │
# │                                            │           │ various symbols including a chain and a    │           │
# │                                            │           │ fox and an eggplant with a red line        │           │
# │                                            │           │ crossing it out.                           │           │
# │ white fur                                  │    158    │ The tiger has a bell on the end of its     │     1     │
# │                                            │           │ tail.                                      │           │
# │ hair                                       │    146    │ The fox is naked and has a fluffy tail     │     1     │
# │                                            │           │ that ends in white.                        │           │
# │ digital media \(artwork\)                  │    139    │ Both characters have green eyes.           │     1     │
# │ smile                                      │    112    │ The fox has a blush on it's face.          │     1     │
# │ eyes closed                                │    107    │ This image is a furry sticker of two       │     1     │
# │                                            │           │ anthro animals one that appears to be an   │           │
# │                                            │           │ fox and the other a ych.                   │           │
# │ fox                                        │    105    │ The fox is orange and white with its eyes  │     1     │
# │                                            │           │ closed and a content expression while the  │           │
# │                                            │           │ anthro ych is blue and white.              │           │
# │ tuft                                       │    94     │ The fox is petting the anthro ych's head.  │     1     │
# │ outline                                    │    93     │ Above the anthro ych there's a text that   │     1     │
# │                                            │           │ reads 'PAT PAT' indicating the action      │           │
# │                                            │           │ being depicted.                            │           │
# │ open mouth                                 │    92     │ The fox has a white outline and the ych a  │     1     │
# │                                            │           │ blue outline around it.                    │           │
# │ red body                                   │    77     │ This furry sticker depicts an anthro fox   │     1     │
# │                                            │           │ with orange fur and green eyes.            │           │
# │ tongue                                     │    75     │ It has a playful expression.               │     1     │
# │ red fur                                    │    75     │ The anthro fox is shown in a pose while    │     1     │
# │                                            │           │ talking with its mouth open and its hands  │           │
# │                                            │           │ at its chest.                              │           │
# │ text                                       │    73     │ The background is transparent putting      │     1     │
# │                                            │           │ emphasis on the fox character.             │           │
# │ markings                                   │    70     │ The character has a white outline around   │     1     │
# │                                            │           │ it.                                        │           │
# │ canis                                      │    69     │ This furry sticker is a stylized animated  │     1     │
# │                                            │           │ depiction of an anthro fox.                │           │
# │ telegram sticker                           │    68     │ The character has an orange fur coat and   │     1     │
# │                                            │           │ white underbelly.                          │           │
# │ clothing                                   │    53     │ It has green eyes and is wearing a blue    │     1     │
# │                                            │           │ collar with a silver buckle.               │           │
# │ brown body                                 │    53     │ It is tilting its head to the side         │     1     │
# │                                            │           │ displaying a playful or curious            │           │
# │                                            │           │ expression.                                │           │
# │ brown fur                                  │    53     │ There are small white lines above its head │     1     │
# │                                            │           │ suggesting thought.                        │           │
# │ felid                                      │    51     │ thinking                                   │     1     │
# │ black hair                                 │    50     │ This is furry sticker of an anthro fox.    │     1     │
# │ ambiguous gender                           │    49     │ The fox is depicted in a thoughtful pose   │     1     │
# │                                            │           │ with one hand on its chin and a slightly   │           │
# │                                            │           │ furrowed brow as if it's pondering.        │           │
# │ portrait                                   │    49     │ The fox has a red and brown coat with      │     1     │
# │                                            │           │ white underbelly and a tail that is red at │           │
# │                                            │           │ the base and white at the tip.             │           │
# │ blush                                      │    48     │ The fox has green eyes and is wearing a    │     1     │
# │                                            │           │ small grey hat.                            │           │
# │ teeth                                      │    45     │ There's also a blue circle with an 'X' in  │     1     │
# │                                            │           │ it next to the fox which indicates         │           │
# │                                            │           │ something wrong or incorrect and it is     │           │
# │                                            │           │ doubting it.                               │           │
# │ tail                                       │    45     │ The character and button has a small white │     1     │
# │                                            │           │ outline around them.                       │           │
# │ domestic dog                               │    44     │ solo focus                                 │     1     │
# │ reaction image                             │    42     │ disembodied hand                           │     1     │
# │ feline                                     │    41     │ pizza                                      │     1     │
# │ blue eyes                                  │    39     │ curled up                                  │     1     │
# │ grey body                                  │    38     │ kerchief                                   │     1     │
# │ duo                                        │    37     │ bandanna                                   │     1     │
# │ headgear                                   │    36     │ skunk                                      │     1     │
# │ grey fur                                   │    34     │ mephitid                                   │     1     │
# │ headwear                                   │    34     │ purple eyes                                │     1     │
# │ white background                           │    33     │ half-closed eyes                           │     1     │
# │ hat                                        │    33     │ ponytail                                   │     1     │
# │ pawpads                                    │    32     │ star                                       │     1     │
# │ black nose                                 │    32     │ unimpressed                                │     1     │
# │ red panda                                  │    32     │ viverrid                                   │     1     │
# │ ailurid                                    │    31     │ legwear                                    │     1     │
# │ brown hair                                 │    30     │ skirt                                      │     1     │
# │ felis                                      │    30     │ armwear                                    │     1     │
# │ collar                                     │    29     │ arm warmers                                │     1     │
# │ domestic cat                               │    29     │ pink clothing                              │     1     │
# │ clothed                                    │    28     │ thigh highs                                │     1     │
# │ orange fur                                 │    28     │ pattern legwear                            │     1     │
# │ tongue out                                 │    28     │ striped clothing                           │     1     │
# │ spitz                                      │    28     │ striped legwear                            │     1     │
# │ gesture                                    │    27     │ pattern clothing                           │     1     │
# │ orange body                                │    26     │ stockings                                  │     1     │
# │ yellow eyes                                │    25     │ drinking straw                             │     1     │
# │ looking at viewer                          │    24     │ motorcycle                                 │     1     │
# │ black body                                 │    23     │ helmet                                     │     1     │
# │ blue body                                  │    23     │ headgear only                              │     1     │
# │ paws                                       │    22     │ sparkles                                   │     1     │
# │ blue fur                                   │    21     │ weights                                    │     1     │
# │ black fur                                  │    20     │ weightlifting                              │     1     │
# │ female                                     │    20     │ workout                                    │     1     │
# │ feral                                      │    20     │ dumbbell                                   │     1     │
# │ shiba inu                                  │    20     │ exercise                                   │     1     │
# │ <3                                         │    20     │ nipples                                    │     1     │
# │ blue hair                                  │    19     │ yellow nose                                │     1     │
# │ holding object                             │    19     │ inflatable                                 │     1     │
# │ diaper                                     │    19     │ pool toy                                   │     1     │
# │ speech bubble                              │    18     │ synth \(vader-san\)                        │     1     │
# │ rating_questionable                        │    17     │ machine                                    │     1     │
# │ green eyes                                 │    17     │ robot                                      │     1     │
# │ lagomorph                                  │    16     │ controller                                 │     1     │
# │ leporid                                    │    16     │ game controller                            │     1     │
# │ rabbit                                     │    16     │ gaming                                     │     1     │
# │ young                                      │    16     │ holding controller                         │     1     │
# │ pink nose                                  │    15     │ holding game controller                    │     1     │
# │ food                                       │    14     │ playing videogame                          │     1     │
# │ tail markings                              │    14     │ apple                                      │     1     │
# │ procyonid                                  │    13     │ This image is a stylized cartoonish        │     1     │
# │                                            │           │ sticker of an anthro red panda's face.     │           │
# │ blue nose                                  │    13     │ It has a light purple fur with large       │     1     │
# │                                            │           │ expressive eyes and an open mouth which    │           │
# │                                            │           │ appears to be shouting.                    │           │
# │ bodily fluids                              │    12     │ There is also a signature on the bottom    │     1     │
# │                                            │           │ left corner of it's ear.                   │           │
# │ dialogue                                   │    11     │ pacifier                                   │     1     │
# │ multicolored hair                          │    11     │ holding object in mouth                    │     1     │
# │ pink pawpads                               │    11     │ clenched teeth                             │     1     │
# │ pantherine                                 │    10     │ flag                                       │     1     │
# │ eyewear                                    │    10     │ holding flag                               │     1     │
# │ cub                                        │    10     │ flag \(object\)                            │     1     │
# │ nordic sled dog                            │    10     │ united states of america                   │     1     │
# │ fingers                                    │    10     │ stars and stripes                          │     1     │
# │ dipstick tail                              │    10     │ pride color flag                           │     1     │
# │ tan fur                                    │    10     │ diaper only                                │     1     │
# │ sleeping                                   │     9     │ chibi                                      │     1     │
# │ beverage                                   │     9     │ white clothing                             │     1     │
# │ buckteeth                                  │     9     │ on front                                   │     1     │
# │ embrace                                    │     9     │ backwards baseball cap                     │     1     │
# │ topwear                                    │     9     │ rainbow pride colors                       │     1     │
# │ sticker                                    │     8     │ rainbow symbol                             │     1     │
# │ raccoon                                    │     8     │ six-stripe rainbow pride colors            │     1     │
# │ pink body                                  │     8     │ cheetah                                    │     1     │
# │ hug                                        │     8     │ yellow body                                │     1     │
# │ glasses                                    │     8     │ yellow sclera                              │     1     │
# │ angry                                      │     8     │ chopsticks                                 │     1     │
# │ brown eyes                                 │     8     │ surprised expression                       │     1     │
# │ one eye closed                             │     8     │ v sign                                     │     1     │
# │ male/male                                  │     8     │ crown                                      │     1     │
# │ red fox                                    │     7     │ royalty                                    │     1     │
# │ sitting                                    │     7     │ king                                       │     1     │
# │ nude                                       │     7     │ giant panda                                │     1     │
# │ wolf                                       │     7     │ towel                                      │     1     │
# │ horn                                       │     7     │ wet                                        │     1     │
# │ piercing                                   │     6     │ wet body                                   │     1     │
# │ topless                                    │     6     │ multicolored body                          │     1     │
# │ spots                                      │     6     │ yelling                                    │     1     │
# │ frown                                      │     6     │ screaming                                  │     1     │
# │ lying                                      │     6     │ annoyed                                    │     1     │
# │ pink fur                                   │     6     │ burger                                     │     1     │
# │ clean diaper                               │     6     │ tail hug                                   │     1     │
# │ tears                                      │     6     │ yawn                                       │     1     │
# │ happy                                      │     6     │ necktie                                    │     1     │
# │ lucario                                    │     6     │ hand heart                                 │     1     │
# │ digital media \\(artwork\\)                │     5     │ strawberry                                 │     1     │
# │ hyena                                      │     5     │ melee weapon                               │     1     │
# │ icon                                       │     5     │ sword                                      │     1     │
# │ headshot portrait                          │     5     │ holding weapon                             │     1     │
# │ bottomwear                                 │     5     │ knife                                      │     1     │
# │ container                                  │     5     │ fire                                       │     1     │
# │ purple body                                │     5     │ name badge                                 │     1     │
# │ blue clothing                              │     5     │ licking lips                               │     1     │
# │ wearing diaper                             │     5     │ self licking own lips                      │     1     │
# │ curled tail                                │     5     │ cake                                       │     1     │
# │ crying                                     │     5     │ dessert                                    │     1     │
# │ waving                                     │     5     │ birthday                                   │     1     │
# │ cuddling                                   │     5     │ party hat                                  │     1     │
# │ pokemon \(species\)                        │     5     │ birthday cake                              │     1     │
# │ generation 4 pokemon                       │     5     │ candle                                     │     1     │
# │ red eyes                                   │     5     │ dipstick tail markings                     │     1     │
# │ butt                                       │     4     │ popcorn                                    │     1     │
# │ looking back                               │     4     │ paper                                      │     1     │
# │ feet                                       │     4     │ blanket                                    │     1     │
# │ spotted hyena                              │     4     │ bedding                                    │     1     │
# │ fangs                                      │     4     │ on bed                                     │     1     │
# │ vehicle                                    │     4     │ tired                                      │     1     │
# │ head tuft                                  │     4     │ holding cup                                │     1     │
# │ blep                                       │     4     │ chain                                      │     1     │
# │ equid                                      │     4     │ hand on face                               │     1     │
# │ equine                                     │     4     │ keyboard                                   │     1     │
# │ horse                                      │     4     │ multicolored fur                           │     1     │
# │ purple fur                                 │     4     │ cigarette                                  │     1     │
# │ snow leopard                               │     4     │ boop                                       │     1     │
# │ pillow                                     │     4     │ laugh                                      │     1     │
# │ welsh corgi                                │     4     │ money                                      │     1     │
# │ wink                                       │     4     │ tail in mouth                              │     1     │
# │ claws                                      │     4     │ middle finger                              │     1     │
# │ kissing                                    │     4     │ biped                                      │     1     │
# │ dragon                                     │     4     │ multicolored tail markings                 │     1     │
# │ tan body                                   │     4     │ black background                           │     1     │
# │ bell                                       │     4     │ membranous wings                           │     1     │
# │ tabby cat                                  │     4     │ membrane \(anatomy\)                       │     1     │
# │ white outline                              │     3     │ sound effects                              │     1     │
# │ african wild dog                           │     3     │ petting                                    │     1     │
# │ surprise                                   │     3     │ hand on head                               │     1     │
# │ eating                                     │     3     │ tail motion                                │     1     │
# │ arctic fox                                 │     3     │ tailwag                                    │     1     │
# │ breasts                                    │     3     │ cellphone                                  │     1     │
# │ crossed arms                               │     3     │ cookie                                     │     1     │
# │ chest tuft                                 │     3     │ feces                                      │     1     │
# │ coffee                                     │     3     │ scat                                       │     1     │
# │ cup                                        │     3     │ chocolate                                  │     1     │
# │ coffee mug                                 │     3     │ long ears                                  │     1     │
# │ ears down                                  │     3     │ rear view                                  │     1     │
# │ bridle                                     │     3     │ musteline                                  │     1     │
# │ fruit                                      │     3     │ domestic ferret                            │     1     │
# │ plant                                      │     3     │ oral                                       │     1     │
# │ phone                                      │     3     │ weasel                                     │     1     │
# │ vowelless sound effect                     │     3     │ bowl                                       │     1     │
# │ husky                                      │     3     │ saliva                                     │     1     │
# │ zzz                                        │     3     │ mind control                               │     1     │
# │ baseball cap                               │     3     │ hypnosis                                   │     1     │
# │ spotted fur                                │     3     │ drooling                                   │     1     │
# │ spotted body                               │     3     │ spiral eyes                                │     1     │
# │ sex                                        │     3     │ bell collar                                │     1     │
# │ border                                     │     3     │ tongue outline                             │     1     │
# │ white border                               │     3     │ bottomless                                 │     1     │
# │ sweat                                      │     3     │ yarn                                       │     1     │
# │ highlights \(coloring\)                    │     3     │ red collar                                 │     1     │
# │ wings                                      │     3     │ cape                                       │     1     │
# │ half-length portrait                       │     3     │ generation 4 pokemon \(species\)           │     1     │
# │ bust portrait                              │     3     │ scarf                                      │     1     │
# │ inner ear fluff                            │     3     │ t-shirt                                    │     1     │
# │ computer                                   │     3     │ pants                                      │     1     │
# │ blue tongue                                │     3     │ neck tuft                                  │     1     │
# │ shirt                                      │     3     │ facial tuft                                │     1     │
# │ hoodie                                     │     3     │ cheek tuft                                 │     1     │
# │ marine                                     │     3     │ green body                                 │     1     │
# │ headphones                                 │     2     │ green fur                                  │     1     │
# │ toes                                       │     2     │ belly                                      │     1     │
# │ white hair                                 │     2     │ sign                                       │     1     │
# │ narrowed eyes                              │     2     │ holding sign                               │     1     │
# │ striped tail                               │     2     │ orange hair                                │     1     │
# │ striped markings                           │     2     │ dalmatian                                  │     1     │
# │ stripes                                    │     2     │ card                                       │     1     │
# │ girly                                      │     2     │ black tail                                 │     1     │
# │ straw                                      │     2     │ raised arm                                 │     1     │
# │ drinking                                   │     2     │ black spots                                │     1     │
# │ sunglasses                                 │     2     │ fin                                        │     1     │
# │ ear piercing                               │     2     │ frill \(anatomy\)                          │     1     │
# │ pivoted ears                               │     2     │ head fin                                   │     1     │
# │ scalie                                     │     2     │ bow tie                                    │     1     │
# │ vowelless                                  │     2     │ alcohol                                    │     1     │
# │ pillow hug                                 │     2     │ samoyed                                    │     1     │
# │ lgbt pride colors                          │     2     │ bow \(feature\)                            │     1     │
# │ question mark                              │     2     │ glass container                            │     1     │
# │ backwards hat                              │     2     │ featureless breasts                        │     1     │
# │ sad                                        │     2     │ hybrid                                     │     1     │
# │ rainbow                                    │     2     │ fennec                                     │     1     │
# │ yellow fur                                 │     2     │ romantic                                   │     1     │
# │ melanistic                                 │     2     │ cum                                        │     1     │
# │ on back                                    │     2     │ penis                                      │     1     │
# │ featureless crotch                         │     2     │ genital fluids                             │     1     │
# │ bear                                       │     2     │ genitals                                   │     1     │
# │ overweight                                 │     2     │ ejaculation                                │     1     │
# │ confetti                                   │     2     │ cumshot                                    │     1     │
# │ holding tail                               │     2     │ orgasm                                     │     1     │
# │ fluffy                                     │     2     │ erection                                   │     1     │
# │ weapon                                     │     2     │ hands-free                                 │     1     │
# │ car                                        │     2     │ cum while penetrated                       │     1     │
# │ driving                                    │     2     │ cum inside                                 │     1     │
# │ inside car                                 │     2     │ humanoid genitalia                         │     1     │
# │ multicolored tail                          │     2     │ humanoid penis                             │     1     │
# │ bed                                        │     2     │ penetration                                │     1     │
# │ furniture                                  │     2     │ cowgirl position                           │     1     │
# │ romantic couple                            │     2     │ on bottom                                  │     1     │
# │ stretching                                 │     2     │ male penetrated                            │     1     │
# │ gloves \(marking\)                         │     2     │ on top                                     │     1     │
# │ halo                                       │     2     │ anal                                       │     1     │
# │ green hair                                 │     2     │ antelope                                   │     1     │
# │ black eyes                                 │     2     │ bovid                                      │     1     │
# │ mustelid                                   │     2     │ gazelle                                    │     1     │
# │ rating_explicit                            │     2     │ caprine                                    │     1     │
# │ glass                                      │     2     │ otter                                      │     1     │
# │ leash                                      │     2     │ whiskers                                   │     1     │
# │ fish                                       │     2     │ blonde hair                                │     1     │
# │ 4 fingers                                  │     2     │ shark                                      │     1     │
# │ sergal                                     │     1     │ leash pull                                 │     1     │
# │ pointing                                   │     1     │ herding dog                                │     1     │
# │ This sticker depicts an anthro sergal with │     1     │ pastoral dog                               │     1     │
# │ brown fur                                  │           │                                            │           │
# │ The sergal has pointed ears and a long     │     1     │ german shepherd                            │     1     │
# │ tail behind his back.                      │           │                                            │           │
# │ The character is shown with its mouth wide │     1     │ humor                                      │     1     │
# │ open as if it's shouting or calling out    │           │                                            │           │
# │ for food.                                  │           │                                            │           │
# │ Above the character there is a speech      │     1     │ This image is a furry sticker of a german  │     1     │
# │ bubble that reads 'FOOD'.                  │           │ shepherd dog with a humorous expression.   │           │
# │ facial piercing                            │     1     │ It is accompanied by a speech bubble with  │     1     │
# │                                            │           │ 'I DON'T KNOW MAN I'M JUST A DOG.,'        │           │
# │                                            │           │ written in it.                             │           │
# │ underwear                                  │     1     │ The canine appears to be shrugging with    │     1     │
# │                                            │           │ its paws raised and wearing dog tag.       │           │
# │ nose piercing                              │     1     │ The background is transparent and the      │     1     │
# │                                            │           │ overall tone of the image is light-hearted │           │
# │                                            │           │ and comical.                               │           │
# │ raised tail                                │     1     │ The character and the speech bubble has a  │     1     │
# │                                            │           │ white outline around them.                 │           │
# │ This image is a furry sticker of a         │     1     │ smile,                                     │     1     │
# │ stylized anthro hyena.                     │           │                                            │           │
# │ It is depicted in a playful or cheeky pose │     1     │ This image is a sticker featuring a        │     1     │
# │ with its tail raised and wagging.          │           │ cartoonish anthro snow leopard.            │           │
# │ It is looking over its shoulder with a     │     1     │ It has gray fur with black spots and blue  │     1     │
# │ mischievous expression.                    │           │ hair.                                      │           │
# │ The hyena has a blush.                     │     1     │ It is in a playful pose with its mouth     │     1     │
# │                                            │           │ open.                                      │           │
# │  The character is wearing purple shorts    │     1     │ It is saying 'MOW!' inside a speech        │     1     │
# │ and there's a white outline around the     │           │ bubble.                                    │           │
# │ character.                                 │           │                                            │           │
# │ This image is an illustration of an anthro │     1     │ The speech bubble's background is white    │     1     │
# │ fox with a blue hair on its head.          │           │ and the text 'MOW!' is written in large    │           │
# │                                            │           │ bold black letters.                        │           │
# │ The character is in a surprised and        │     1     │ The dialogue box has a black outline and a │     1     │
# │ startled pose.                             │           │ white outline after.                       │           │
# │ With wide eyes and a hand on its chin      │     1     │ lion                                       │     1     │
# │ signifying terror.                         │           │                                            │           │
# │ The fox has a large tail that is half red  │     1     │ mane                                       │     1     │
# │ and half white.                            │           │                                            │           │
# │ The character is wearing headphones of     │     1     │ This sticker depicts an animated anthro    │     1     │
# │ which only one is visible.                 │           │ lion creature with a playful expression.   │           │
# │ There are motion lines around the          │     1     │ It has light and dark brown fur a pink     │     1     │
# │ character and it has its ears down in      │           │ nose and is waving its right cartoonish    │           │
# │ fear.                                      │           │ paw as if greeting someone.                │           │
# │ rubber                                     │     1     │ There is also a speech bubble with the     │     1     │
# │                                            │           │ text "Hey." written inside it above its    │           │
# │                                            │           │ head.                                      │           │
# │ tiger                                      │     1     │                                            │     1     │
# │ skinsuit                                   │     1     │ deer                                       │     1     │
# └────────────────────────────────────────────┴───────────┴────────────────────────────────────────────┴───────────┘
