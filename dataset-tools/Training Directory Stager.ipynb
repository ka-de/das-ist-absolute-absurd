# %% [markdown]
# # Training Directory Tools
# ----
#
# This notebook contains all my magic I use to fiddle around with my datasets.

# %%
# Out:
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\037ceb330a46b3bd01e2bfda92fd66f5.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\0630ce3d01e25eb803781716440bd7b5.txt
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\07b5e552b6b946ebb9c970354c55b198.txt
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\0d281d07dfc997a5b1037939ccd33eca.txt
# - speech
# - outline
# - bubble
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\12cc788a23632fbc5bddbe4a3d0b63c0.txt
# - portrait
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\13f2de85dc85ab31d084254faac0e64d.txt
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\15814659a362c2fff15be0e673226521.txt
# - sticker
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\17536230452b954e4df791723dad4580.txt
# - sticker
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\211ee180a626eb52835735734dfc4bb7.txt
# - body
# - orange
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\2247e5262c163386ef02e80b898ebf56.txt
# - black
# - nose
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\2333f08fee2334f7d4b3c344c7b165bd.txt
# - tuft
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\2707934fd352b2c57e3b0d4ecc9dabce.txt
# - tail
# - markings
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\27b98decdeb7785f4125b81ed94f68c2.txt
# - black
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\2ae636ee5a3b5b8240f11ca4b9083435.txt
# - fur
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\2ecb7e60de62a4cd44b60b342e6fae90.txt
# - tail
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\30d6ffc114678898d41aff759269bd08.txt
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\378f288700a23068be9b02a5e20f0089.txt
# - black
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\388c1ae0764325604192213e60c1bfca.txt
# - fur
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\38e879cee8d41c6f0a5438b99755f99f.txt
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\38e8fe65aa36e15c960f8f1885652de2.txt
# - clothing
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3c0feb90f445fd0a32d2a70d595d9a0f.txt
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3c3c9b21f695ab5433c806acd9d3f635.txt
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3c9a9521c6aeb3183d922648cb5e52bf.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3cabdafe93be70789540d448fc467008.txt
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3d8ba16648ffc52add8bebaba4658b4c.txt
# - hat
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\3eb3b064f1d5a02dfd863d8020fc401b.txt
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\4130b426cf410e21596e60f281ee38d7.txt
# - ych
# - white
# - fox
# - outline
# - blue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\4282a665783c584ea257f74ff6a46a77.txt
# - tail
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\42c5f1f83f399f5f8fbc771d27c99d9d.txt
# - tan
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\438df028b9ca2391503c6a5fc03e4556.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\4896b709d1fe529d7d701fe6b410d0f4.txt
# - character
# - speech
# - bubble
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\498a478e652faa5c9e752a7ee64fc8f1.txt
# - brown
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\49f2e89f4d8e41fce9e577e39555983a.txt
# - tail
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\4d4a6c86398e7c3a3d3dc8c1ea3759f9.txt
# - baseball
# - backwards
# - cap
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\50935ca02b05aef55cf0d32e58dbefe4.txt
# - brown
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\519135b7d7516fb51c1adac0598d7936.txt
# - tail
# - markings
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\51d1cdf4a51c513f026b3f3abbbe1397.txt
# - outline
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\524cea5240f4ac240a9d5bc6b29c5a54.txt
# - brown
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\54f6dc7868e8d46ccbbad81802f8faae.txt
# - black
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\5f3aee505339fa08b8a8c3297ee9cada.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\602c0e8614d456c0b30ac9a9bcf709ac.txt
# - eyes
# - blue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\6051eb48cc66511005af0f9508db3aaa.txt
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\620d760c06a5bf7b2c239e9e9a0dea72.txt
# - black
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\62cfb7b1c3f4e09219d0577d3a79a032.txt
# - body
# - orange
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\6567d263071b20e20b310a7e4fdb0796.txt
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\681220c3bc3ca3d91d79957c543b64e2.txt
# - tongue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\6d7073a91f8a2177f1bb72b90349b489.txt
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\716cc90676e1564438c29e623229a68b.txt
# - tail
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\7447509b0b6888c2fdc241735cd0d794.txt
# - tongue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\7988286454327ebb1771edb658b14309.txt
# - black
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\7b7bd6e31e5116408d9cbfe7b7644e1f.txt
# - white
# - head
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\7d0fbc7247bb4641cad334dbf7e544e4.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\81076519ee4861d3a9584681995a8b68.txt
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\856ebe7246db8561714bfb5aba22bb2e.txt
# - blue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\873dd8107753f1cd4833d02b51bd35a5.txt
# - striped
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\88bc3dd9ed5828e35733363f681d953c.txt
# - dog
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\8ada1d9a1828281bd5a11f2221a436df.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\8df95fb06b447374a48da9ab7dbbf6a1.txt
# - portrait
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\8ff9fb8f16f4843fd6eaa200b130d8da.txt
# - brown
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\93184591c91052a19c64816b4298cbeb.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\934c7a794d226cd73d1e9c8cae5b56fc.txt
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\95bd5a8a7c5773626269259568d75d8f.txt
# - portrait
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\995650eef692b8280ccbd6bd38f1bbae.txt
# - blush
# - face.
# - fox
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\9b9182bcb72d8fdccf0547bc50891135.txt
# - clothing
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\9c39884c1dfb4ef3432b6167cc3dfd5d.txt
# - portrait
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\a6f20fed8abc8ecb1e7d9c6b83f4228f.txt
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\aa5df2d2b7459041276e3d61105dbdfb.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\acfb75bb2aa5b8fad3bbe493d7277623.txt
# - blue
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\ae1aaf847419406463fd603eb2f2242e.txt
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\ae8b7b3b3ae2d9fe5e56823e40d94251.txt
# - fur
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\af645ac16a9c9608b6429837a82b361c.txt
# - outline
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\af6fa406cc9ea41e9fd28c3fce215ec0.txt
# - dog
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b1465a05f7fb760c19fa49a7e4efce51.txt
# - black
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b3cc604f3598e4af4eae34c39e9f4ace.txt
# - brown
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b64915b1372237943505e6b9231e6f39.txt
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b7542304dd6273a2d143ea323bc1bf8a.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b8429d9b777c0dcd4f2cf649f3876a9e.txt
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\b8984c954cd2e75127d00c0216db1c0c.txt
# - black
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\bad5088b4de0289e7677a144d02fd804.txt
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\be3be16b66d6dafe0ac5bc82099094e9.txt
# - black
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\be7859a2d6977b8916f47d17a7b6dfcc.txt
# - eyes
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\c004dd17eabdc650f7870d1cce451132.txt
# - small
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\c0a3f03314f968c0464a104552b25c42.txt
# - black
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\c1ba137c152cb595e7e128fc686faeb0.txt
# - clothing
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\cac45c9aca240c286f0df921e55b3177.txt
# - black
# - spots
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\cca465af9d89d81304a12a6ccf6c59e1.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\d1122ddaf0caeeedf9bf578c129a1674.txt
# - black
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\d11c849157de9141d06b1d877408fe8f.txt
# - sticker
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\d1eb131ede7608a5b3ee0865ed932985.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\d6d4961b3afbd06ea41661204f2b9dcf.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\dd05e2ef9a944127292acef7cb80984b.txt
# - fur
# - brown
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\e4304307cc2e7ad42167b828fd8c4871.txt
# - tail
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\e55c0cacf522e3aa189c8fad59a6fa35.txt
# - sticker
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\eb7463f89440508869c0e22c361161a1.txt
# - fur
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\ecffc0f6df6394bdd1be32f9c77a61fb.txt
# - body
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\f1ff847532e185a197af2f14a1fba805.txt
# - black
# - white
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\f25ee8a4369c725642dcf71dc4e1a558.txt
# - diaper
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\f29cbed94f092e50a2f14873326819ac.txt
# - fingers
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\f4f2495af8cf5cea93a5d73327b56b78.txt
# - black
# - background
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\f9468ada1a62410d8d0891cabe0c538a.txt
# - character
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\fa67f4c4374548f97a807ff26eb765ee.txt
# - hair
# File: C:\Users\kade\Desktop\training_dir_staging\1_furry_sticker\fedcfa34e281226402c2652cac1988d8.txt
# - black

# %% [markdown]
# ## Convert `.webp` to `.png`
# ----
#
# This script converts all WebP images in a specified directory and its subdirectories to PNG format. It utilizes the `os` module to navigate through the directory structure and the `PIL` (Python Imaging Library) module's `Image` class to handle image processing. The function `convert_webp_to_png(directory)` takes a directory path as input, iterates through all files in that directory (including subdirectories), identifies WebP files based on their extension, converts them to PNG format, and saves the converted images in the same location. If conversion is successful, it also removes the original WebP files. If any errors occur during conversion, it prints an error message with details.

# %%
import os
from PIL import Image

def convert_webp_to_png(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.webp'):
                webp_path = os.path.join(root, file)
                png_path = os.path.splitext(webp_path)[0] + '.png'
                try:
                    with Image.open(webp_path) as img:
                        img.save(png_path, format='PNG')

                    os.remove(webp_path)
                    print(f"Converted {webp_path} to {png_path}")
                except Exception as e:
                    print(f"Error converting {webp_path}: {e}")

#directory = r'E:\training_dir'
#directory = r'C:\Users\kade\Desktop\training_dir_staging'
directory = r'C:\Users\kade\Desktop\ayaya'
convert_webp_to_png(directory)
# Out:
# Converted C:\Users\kade\Desktop\ayaya\nap97qc4ilh21.webp to C:\Users\kade\Desktop\ayaya\nap97qc4ilh21.png

# %% [markdown]
# ## Duplicate checker
# ----
#
# This Python script checks for duplicate tags within text files (`.txt`) in a specified directory and its subdirectories. It reads each text file, splits its content into tags separated by commas, and identifies any duplicates. If duplicates are found, it prints out a message indicating the file where the duplicates were found and the duplicate tags themselves. Finally, the `check_tags_in_directory` function iterates through the directory and calls `check_duplicate_tags` for each text file found.

# %%
import os

def check_duplicate_tags(file_path):
    with open(file_path, 'r') as file:
        tags = file.read().split(', ')
        duplicates = set()
        unique_tags = set()
        for tag in tags:
            if tag in unique_tags:
                duplicates.add(tag)
            else:
                unique_tags.add(tag)
        if duplicates:
            print(f"Duplicate tags found in {file_path}: {', '.join(duplicates)}")

def check_tags_in_directory(directory):
    for root, _, files in os.walk(directory):
        for file_name in files:
            if file_name.endswith('.txt'):
                file_path = os.path.join(root, file_name)
                check_duplicate_tags(file_path)

if __name__ == "__main__":
    directory_path = r'C:\Users\kade\Desktop\training_dir_staging'
    check_tags_in_directory(directory_path)

# %% [markdown]
# ## Replace tags and remove duplicates
# ----
#
# This Python script recursively processes text files within a specified directory, replacing occurrences of certain words or phrases with new ones.
#
# It utilizes regular expressions to perform search and replace operations. The main function, `process_files`, accepts a directory path along with old and new tags to be replaced. It searches for `.txt` and `.tags` within the directory and its subdirectories, reads the content of each file, performs replacements based on the provided tags, and then writes the modified content back to the files.

# %%
import os
import re

def process_files(directory, old_tag, new_tag):
    try:
        for entry in os.listdir(directory):
            entry_path = os.path.join(directory, entry)

            if os.path.isdir(entry_path):
                process_files(entry_path, old_tag, new_tag)

            elif os.path.isfile(entry_path) and (entry.endswith(".txt") or entry.endswith(".tags")):
                with open(entry_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                if old_tag:
                    content = re.sub(r'\b' + re.escape(old_tag) + r'\b', new_tag, content)

                tag_pattern = re.compile(r'(\b\w+\b)(?:(?:,|\s)+\1)+')
                content = re.sub(tag_pattern, r'\1', content)

                with open(entry_path, 'w', encoding='utf-8') as f:
                    f.write(content)

    except Exception as e:
        print(f"Error processing directory {directory}: {e}\n")

# Directory path
directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

process_files(directory_path, 'transparent background', 'black background')

#process_files(directory_path, 'safe', 'rating_safe')
#process_files(directory_path, 'questionable', 'rating_questionable')
#process_files(directory_path, 'explicit', 'rating_explicit')

# %% [markdown]
# ## Insert tag
# ----
#
# This script recursively inserts a specified tag at the beginning of each line in both `.txt` and `.tags` files within a given directory and its subdirectories.

# %%
import os

# Function to insert a specified tag in text files in subdirectories
def insert_tag_in_files(directory, tag_to_insert):
    try:
        for entry in os.listdir(directory):
            entry_path = os.path.join(directory, entry)

            if os.path.isdir(entry_path):
                insert_tag_in_files(entry_path, tag_to_insert)

            elif os.path.isfile(entry_path) and (entry.endswith(".txt") or entry.endswith(".tags")):
                with open(entry_path, 'r', encoding='utf-8') as f:
                    content = f.read()

                # Insert the specified tag
                content = tag_to_insert + ', ' + content

                # Write back to the file
                with open(entry_path, 'w', encoding='utf-8') as f:
                    f.write(content)

    except Exception as e:
        print(f"Error processing directory {directory}: {e}\n")

directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

# Execute the function with the desired tag
insert_tag_in_files(directory_path, 'furrysticker')

# %% [markdown]
# ## Escape parentheses
# ----
#
# Recursively escape unescaped parentheses in all `.txt` files within the specified directory and its subdirectories.

# %%
import os
import re

def escape_parentheses(file_path):
    with open(file_path, 'r') as file:
        content = file.read()

    # Escape unescaped parentheses
    content = re.sub(r'(?<!\\)([()])', r'\\\1', content)

    with open(file_path, 'w') as file:
        file.write(content)

def process_directory(directory):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                escape_parentheses(file_path)

                # Recurse into subdirectories
                process_directory(os.path.join(root, file))

directory_path = r'C:\Users\kade\Desktop\training_dir_staging'
process_directory(directory_path)

# %% [markdown]
# ## Replace underscores with spaces
# ----
#
# Recursively replaces underscores with spaces in the content of text files in the specified directory and its subdirectories,
# excluding specified tags.

# %%
import os

excluded_tags = [
    "rating_safe",
    "rating_explicit",
    "rating_questionable"
]

def replace_underscores_with_spaces(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)

                # Read the content of the file
                with open(file_path, 'r') as file:
                    content = file.read()

                # Replace underscores with spaces, excluding specific tags
                for tag in excluded_tags:
                    replacement = tag.replace('_', ' ')
                    content = content.replace(replacement, tag)

                # Write the modified content back to the file
                with open(file_path, 'w') as file:
                    file.write(content)

# Specify the directory path
directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

# Call the function to recursively replace underscores with spaces (excluding specified tags)
replace_underscores_with_spaces(directory_path)

# %% [markdown]
# ### Fix tags that need underscores after that! 🐱
# ----

# %%
import os
import fileinput

# Function to recursively replace text in *.txt files
def replace_text_in_files(directory):
    for subdir, _, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(subdir, file)
                with fileinput.FileInput(file_path, inplace=True) as file:
                    for line in file:
                        print(line.replace("rating safe", "rating_safe")
                                   .replace("rating questionable", "rating_questionable")
                                   .replace("rating explicit", "rating_explicit"), end='')

# Replace text in the specified directory
replace_text_in_files(r'C:\Users\kade\Desktop\training_dir_staging')

# %% [markdown]
# ## Remove extra file extension before `.txt`
# ----
#
# Recursively renames `.txt` files with additional image extensions before in the filename in the specified directory and its subdirectories.

# %%
import os

def rename_files(directory_path):
    for root, dirs, files in os.walk(directory_path):
        for filename in files:
            if filename.endswith('.txt'):
                # Extract the base name without extension
                base_name, extension = os.path.splitext(filename)

                # Check if the file has an additional image extension
                if base_name.endswith(('.png', '.jpg', '.jpeg', '.webp', '.gif')):
                    # Construct the new filename with only the txt extension
                    new_filename = base_name[:-4] + '.txt'

                    # Construct the full file paths
                    old_path = os.path.join(root, filename)
                    new_path = os.path.join(root, new_filename)

                    # Rename the file
                    os.rename(old_path, new_path)

# Specify the directory path
directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

# Call the function to recursively rename files
rename_files(directory_path)

# %% [markdown]
# ## Newlines to commas
# ----
#
# Recursively modify the content of `.txt` files in the specified directory and its subdirectories by replacing newlines with commas and spaces.

# %%
import os

def process_directory(directory):
    for root, dirs, files in os.walk(directory):
        for filename in files:
            if filename.endswith(".txt"):
                file_path = os.path.join(root, filename)
                
                # Read the content of the file
                with open(file_path, 'r') as file:
                    content = file.read()
                
                # Replace newline with a comma and space
                modified_content = content.replace('\n', ', ')
                
                # Write the modified content back to the file
                with open(file_path, 'w') as file:
                    file.write(modified_content)

# Directory path
directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

# Recursively process the directory and its subdirectories
process_directory(directory_path)

# %% [markdown]
# ## Remove tags ⚠️
# ----
#
# This script is designed to remove specific tags from text files (*.txt) located within a given directory and its subdirectories. It iterates through each file, reads its content, removes specified tags, and then overwrites the file with the modified content.
#
# The tags to be removed are specified in the `tags_to_remove` list within the `remove_tags` function. These tags include various strings, such as certain species names, phrases like "unavailable at source," years from 1996 to 2024, and phrases like "generation X pokemon." The script constructs regular expressions to match both escaped and non-escaped occurrences of parentheses in the tags.
#
# The `remove_tags` function takes a file path as input and returns a list of removal actions performed, indicating which tags were removed from which files.
#
# The `process_directory` function recursively processes all files within a specified directory and its subdirectories. For each file with a ".txt" extension, it calls the `remove_tags` function to remove tags and accumulates removal actions. Finally, it prints out all removal actions performed.
#
# To utilize the script, provide the path to the directory containing the text files that need tag removal. Upon execution, the script will modify the files in place, removing the specified tags, and output a log of removal actions.

# %%
import os
import re

def remove_tags(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    tags_to_remove = [
        "creative commons",
        "cc-by-nc-nd",
        "pal (species)",
        "pocketpair",
        "unavailable at source",
        "partially",
        "pokemon (species)",
        "generation",
        "pokephilia",
        "pokemon",
        "nintendo",
        "eeveelution",
        "uncensored",
        "translated",
        "partially translated",
        "translation request",
        "16 10",
        "16 9",
        "10 16",
        "9 16",
        "6 5",
        "5 6",
        "5 4",
        "4 3",
        "4 5",
        "3 4",
        "3 2",
        "2 3",
        "2 1",
        "1 2",
        "1 1",
        "4k",
        "absurd res",
        "hi res",
        "elden ring",
        "fromsoftware",
        "canid",
        "canis",
        "mammal",
        "unwanted erection",
        "lighting",
        "shaded",
        "widescreen"
    ]

    for gen in range(1, 10):
        tags_to_remove.append(f"generation {gen} pokemon")

    for year in range(1996, 2025):
        tags_to_remove.append(str(year))

    removal_actions = []

    for tag in tags_to_remove:
        # Construct regular expression to match both escaped and non-escaped occurrences of parentheses
        pattern = re.compile(re.escape(tag.replace('(', '\(').replace(')', '\)')) + r'|' + tag.replace('(', '\(').replace(')', '\)'))
        if pattern.search(content):
            content = pattern.sub('', content)
            removal_actions.append(f'Removed tag "{tag}" from file: {file_path}')

    with open(file_path, 'w', encoding='utf-8') as file:
        file.write(content)

    return removal_actions

def process_directory(directory):
    all_removal_actions = []

    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                removal_actions = remove_tags(file_path)
                all_removal_actions.extend(removal_actions)

    for action in all_removal_actions:
        print(action)

# Provide the path to the directory
directory_path = r'C:\Users\kade\Desktop\training_dir_staging'

# Recursively remove tags from *.txt files in the specified directory and print removal actions
process_directory(directory_path)

# %% [markdown]
# ### Replace `, ,` with `,` after that mess. 😼
# ----

# %%
import os

# Start directory
start_dir = r'C:\Users\kade\Desktop\training_dir_staging'

# Function to replace text in *.txt files
def replace_text_in_files(directory):
    while True:  # Run indefinitely until no more matches are found
        found_match = False  # Flag to track if any match is found
        for root, dirs, files in os.walk(directory):
            for file in files:
                if file.endswith(".txt"):
                    file_path = os.path.join(root, file)
                    with open(file_path, 'r', encoding='utf-8') as f:
                        content = f.read()
                    # Replace ', ,' with ','
                    updated_content = content.replace(', ,', ',').replace(',  ,', ',')
                    if updated_content != content:
                        found_match = True  # Set the flag to True if any match is found
                        with open(file_path, 'w', encoding='utf-8') as f:
                            f.write(updated_content)
        if not found_match:  # If no match is found, break the loop
            break

# Run the function
replace_text_in_files(start_dir)
